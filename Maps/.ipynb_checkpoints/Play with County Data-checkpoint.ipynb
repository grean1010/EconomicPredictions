# %%
import sys
import json
import csv 
import os
import pandas as pd

# %%
raw_loc = os.path.join('RawData')
clean_loc = os.path.join('static','assets','geojson')

# %%
big_geojson = os.path.join(raw_loc,'US_HistCounties_Gen05.json')
big_geojson
# Out:
# 'RawData\\US_HistCounties_Gen05.json'

# %%
# use 1982 as a test year
year2find = 1982

# create a reference to the output file
outfile = os.path.join(raw_loc,f'Test_GeoFile{year2find}.json')

# Create a blank list of the features we will keep
features = []

# initialize a count of all records on the big geojson file
geojson_count = 0

# Open up the existing geojson file and read it into the empty geojson dictionary created above.
# While reading it in, pull the matching state and county fips from the empdata dictionary so we can add the unemployment info to the geojson.
with open(big_geojson, 'r') as f:
    temp = json.load(f)
    
    for feature in temp['features']:
        geojson_count = geojson_count + 1
        featureProperties = feature['properties']
        fips = featureProperties['FIPS']
        start_year = int(featureProperties["START_DATE"][0:4])
        end_year = int(featureProperties["END_DATE"][0:4])
        
        if start_year <= year2find and year2find <= end_year:
            features.append(feature)

print(f"Records read from large geojson file: {geojson_count}")
print(f"Records that were kept: {len(features)}")

# Output a new geojson file specific to this year.
with open(outfile,'w') as f:
    f.write('{"type":"FeatureCollection","features": [')
    for feature in features:
        json.dump(feature, f)
        f.write(',\n')
    f.write(']}')
# Out:
# Records read from large geojson file: 17727
# Records that were kept: 3142

# %%
xlsfile = os.path.join(raw_loc,'GeoFRED_Per_Capita_Personal_Income_by_County_Dollars2.xls')
xl = pd.ExcelFile(xlsfile)
pcpi = xl.parse('Sheet0')
cols_in = pcpi.columns
cols_rename = []

for col in cols_in:
    if col == 'Region Code':
        cols_rename.append('FIPS')
    elif col in ('Series ID','Region Name'):
        cols_rename.append('DROP')
    elif int(col) >= 2001:
        cols_rename.append(f"PCPI_{col}")
    else:
        cols_rename.append('DROP')

pcpi.columns = cols_rename
pcpi.drop(columns =['DROP'], inplace = True) 
pcpi["In PCPI"] = 1

# Make sure the fips codes have leading zeros.
for obs in range(0,len(pcpi)):
    if len(str(pcpi.loc[obs,'FIPS'])) == 4:
        pcpi.loc[obs,'FIPS'] = f"0{pcpi.loc[obs,'FIPS']}"
    else:
        pcpi.loc[obs,'FIPS'] = f"{pcpi.loc[obs,'FIPS']}"
        
    # 46113 was renamed from Shannon County to Oglala Lakota County, SD in May 2015.  Oglala should have FIPS 46102 but
    # 46102 is not found on the big geojson file so we reset 46102 to 46113.
    if str(pcpi.loc[obs,'FIPS']) == '46102':
        pcpi.loc[obs,'FIPS'] = '46113'
        
    # Calculate percent change in PCPI
    for year in range (2002,2018):
        pyear = year - 1
        pcpi.loc[obs,f'PCPI_PctChange_{year}'] = round(100 * (pcpi.loc[obs,f'PCPI_{year}'] - pcpi.loc[obs,f'PCPI_{pyear}'])/pcpi.loc[obs,f'PCPI_{year}'],2)

pcpi.head()
# Out:
#     FIPS  PCPI_2001  PCPI_2002  PCPI_2003  PCPI_2004  PCPI_2005  PCPI_2006  \
# 0  45001    23201.0    21528.0    20359.0    21756.0    22375.0    23410.0
# 1  22001    21019.0    21565.0    22264.0    22569.0    24134.0    25908.0
# 2  51001    21119.0    22156.0    23971.0    25337.0    26630.0    27828.0
# 3  16001    33528.0    34195.0    34676.0    36657.0    37544.0    40471.0
# 4  29001    21125.0    21065.0    21269.0    22361.0    23133.0    24114.0
#
#    PCPI_2007  PCPI_2008  PCPI_2009  ...  PCPI_PctChange_2008  \
# 0    24311.0    25712.0      25702  ...                 5.45
# 1    27751.0    31483.0      31140  ...                11.85
# 2    29914.0    32114.0      32607  ...                 6.85
# 3    40561.0    39479.0      37727  ...                -2.74
# 4    25295.0    26552.0      27800  ...                 4.73
#
#    PCPI_PctChange_2009  PCPI_PctChange_2010  PCPI_PctChange_2011  \
# 0                -0.04                 3.44                 3.82
# 1                -1.10                 1.36                 3.74
# 2                 1.51                 2.83                 1.27
# 3                -4.64                 1.43                 3.47
# 4                 4.49                -2.36                 4.39
#
#    PCPI_PctChange_2012  PCPI_PctChange_2013  PCPI_PctChange_2014  \
# 0                -0.44                 2.26                 4.42
# 1                 4.81                 4.89                 2.96
# 2                 4.32                 1.51                 3.11
# 3                 4.40                 3.23                 5.31
# 4                 0.74                 2.04                 2.73
#
#    PCPI_PctChange_2015  PCPI_PctChange_2016  PCPI_PctChange_2017
# 0                 4.62                 2.70                 3.81
# 1                -4.65                -4.44                 3.51
# 2                 4.08                 0.75                 3.94
# 3                 5.06                 1.54                 2.97
# 4                 3.54                 0.15                 2.66
#
# [5 rows x 35 columns]

# %%
xlsfile = os.path.join(raw_loc,'GeoFRED_Unemployment_Rate_by_County_Percent2.xls')
xl = pd.ExcelFile(xlsfile)
df0 = xl.parse('Sheet0')
df0.drop(columns =['Series ID'], inplace = True) 
df0.head()
# Out:
#             Region Name  Region Code  1976 January  1976 February  1976 March  \
# 0  Abbeville County, SC        45001           NaN            NaN         NaN
# 1     Acadia Parish, LA        22001           NaN            NaN         NaN
# 2   Accomack County, VA        51001           NaN            NaN         NaN
# 3        Ada County, ID        16001           NaN            NaN         NaN
# 4      Adair County, IA        19001           NaN            NaN         NaN
#
#    1976 April  1976 May  1976 June  1976 July  1976 August  ...  1996 April  \
# 0         NaN       NaN        NaN        NaN          NaN  ...         6.1
# 1         NaN       NaN        NaN        NaN          NaN  ...         7.5
# 2         NaN       NaN        NaN        NaN          NaN  ...         9.4
# 3         NaN       NaN        NaN        NaN          NaN  ...         3.4
# 4         NaN       NaN        NaN        NaN          NaN  ...         3.9
#
#    1996 May  1996 June  1996 July  1996 August  1996 September  1996 October  \
# 0       6.6        7.2        9.3          6.7             5.8           5.9
# 1       7.6        7.9        6.9          6.7             6.8           6.4
# 2       8.4        8.3        7.2          7.6             7.9           7.5
# 3       3.0        3.3        3.2          3.1             3.2           3.3
# 4       3.4        3.1        2.8          2.6             2.8           2.6
#
#    1996 November  1996 December  1997 January
# 0            5.5            5.3           6.2
# 1            6.2            5.6           6.1
# 2            9.6           10.3          14.0
# 3            3.2            3.0           3.8
# 4            2.2            2.6           4.2
#
# [5 rows x 255 columns]

# %%
df1 = xl.parse('Sheet1')
df1.drop(columns =['Series ID','Region Name'], inplace = True) 
df1.head()
# Out:
#    Region Code  1997 February  1997 March  1997 April  1997 May  1997 June  \
# 0        45001            9.8         9.0         8.5       8.3        6.4
# 1        22001            4.9         5.2         5.1       4.9        6.2
# 2        51001           13.6        12.7        10.0       8.8        9.6
# 3        16001            3.6         3.3         3.0       2.6        2.9
# 4        19001            3.9         3.4         3.1       2.3        2.6
#
#    1997 July  1997 August  1997 September  1997 October  ...  2017 May  \
# 0        7.4          7.4             4.4           4.0  ...       4.1
# 1        5.7          8.9             9.3           4.8  ...       5.9
# 2        6.4          6.9             6.8           6.2  ...       4.1
# 3        2.9          2.9             3.0           3.0  ...       2.6
# 4        2.2          2.3             2.4           2.1  ...       2.5
#
#    2017 June  2017 July  2017 August  2017 September  2017 October  \
# 0        4.9        5.4          5.2             4.5           4.3
# 1        6.6        6.2          6.2             5.7           5.1
# 2        4.0        4.1          4.3             3.9           3.9
# 3        2.7        2.7          2.6             2.5           2.4
# 4        2.5        2.3          2.5             2.5           2.0
#
#    2017 November  2017 December  2018 January  2018 February
# 0            4.2            4.3           5.1            4.3
# 1            4.9            4.6           5.5            5.0
# 2            3.9            4.5           5.2            5.2
# 3            2.7            2.6           3.3            3.1
# 4            2.0            2.7           3.6            3.7
#
# [5 rows x 254 columns]

# %%
df2 = xl.parse('Sheet2')
df2.drop(columns =['Series ID','Region Name'], inplace = True) 
df2.head()
# Out:
#    Region Code  2018 March  2018 April  2018 May  2018 June  2018 July  \
# 0        45001         3.9         3.1       3.3        4.4        4.3
# 1        22001         5.1         4.9       5.2        6.7        6.1
# 2        51001         4.6         3.5       3.4        3.6        3.5
# 3        16001         2.9         2.5       2.2        2.3        2.3
# 4        19001         3.0         2.6       2.0        2.2        2.0
#
#    2018 August  2018 September  2018 October  2018 November  2018 December  \
# 0          4.3             3.9           3.9            3.5            3.8
# 1          5.8             5.4           5.0            4.8            4.8
# 2          3.6             3.2           3.1            3.1            3.8
# 3          2.2             2.1           2.1            2.3            2.4
# 4          2.1             1.9           1.7            1.7            2.1
#
#    2019 January  2019 February  2019 March  2019 April  2019 May  2019 June  \
# 0           4.4            3.6         3.8         3.3       3.9        4.2
# 1           5.7            4.8         4.2         3.9       4.6        5.8
# 2           5.1            4.8         4.0         3.3       3.3        3.2
# 3           3.3            2.9         2.7         2.2       2.1        2.4
# 4           2.9            2.9         2.7         2.0       1.9        2.1
#
#    2019 July
# 0        3.8
# 1        5.5
# 2        3.1
# 3        2.5
# 4        2.1

# %%
unemp = pd.merge(df0,pd.merge(df1,df2,on='Region Code'),on='Region Code')
unemp.head()
# Out:
#             Region Name  Region Code  1976 January  1976 February  1976 March  \
# 0  Abbeville County, SC        45001           NaN            NaN         NaN
# 1     Acadia Parish, LA        22001           NaN            NaN         NaN
# 2   Accomack County, VA        51001           NaN            NaN         NaN
# 3        Ada County, ID        16001           NaN            NaN         NaN
# 4      Adair County, IA        19001           NaN            NaN         NaN
#
#    1976 April  1976 May  1976 June  1976 July  1976 August  ...  2018 October  \
# 0         NaN       NaN        NaN        NaN          NaN  ...           3.9
# 1         NaN       NaN        NaN        NaN          NaN  ...           5.0
# 2         NaN       NaN        NaN        NaN          NaN  ...           3.1
# 3         NaN       NaN        NaN        NaN          NaN  ...           2.1
# 4         NaN       NaN        NaN        NaN          NaN  ...           1.7
#
#    2018 November  2018 December  2019 January  2019 February  2019 March  \
# 0            3.5            3.8           4.4            3.6         3.8
# 1            4.8            4.8           5.7            4.8         4.2
# 2            3.1            3.8           5.1            4.8         4.0
# 3            2.3            2.4           3.3            2.9         2.7
# 4            1.7            2.1           2.9            2.9         2.7
#
#    2019 April  2019 May  2019 June  2019 July
# 0         3.3       3.9        4.2        3.8
# 1         3.9       4.6        5.8        5.5
# 2         3.3       3.3        3.2        3.1
# 3         2.2       2.1        2.4        2.5
# 4         2.0       1.9        2.1        2.1
#
# [5 rows x 525 columns]

# %%
cols_in = unemp.columns
print('Original Column Names:')
print(cols_in)
cols_rename = []

for col in cols_in:
    
    if col == 'Region Code':
        cols_rename.append('FIPS')
    elif col in ('Series ID','Region Name') or col[0:3] in ('198','197'):
        cols_rename.append('DROP')
    elif "January" in col:
        cols_rename.append(f"Unemp_{col[0:4]}01")
    elif "February" in col:
        cols_rename.append(f"Unemp_{col[0:4]}02")
    elif "March" in col:
        cols_rename.append(f"Unemp_{col[0:4]}03")
    elif "April" in col:
        cols_rename.append(f"Unemp_{col[0:4]}04")
    elif "May" in col:
        cols_rename.append(f"Unemp_{col[0:4]}05")
    elif "June" in col:
        cols_rename.append(f"Unemp_{col[0:4]}06")
    elif "July" in col:
        cols_rename.append(f"Unemp_{col[0:4]}07")
    elif "August" in col:
        cols_rename.append(f"Unemp_{col[0:4]}08")
    elif "September" in col:
        cols_rename.append(f"Unemp_{col[0:4]}09")
    elif "October" in col:
        cols_rename.append(f"Unemp_{col[0:4]}10")
    elif "November" in col:
        cols_rename.append(f"Unemp_{col[0:4]}11")
    elif "December" in col:
        cols_rename.append(f"Unemp_{col[0:4]}12")
    else:
        cols_rename.append(col)

print('Renamed Column Names:')
print(cols_rename)

# Reset the column names
unemp.columns = cols_rename

# Get rid of dropped columns
unemp.drop(columns =['DROP'], inplace = True) 
unemp["In Unemp"] = 1


# Make sure the fips codes have leading zeros.
for obs in range(0,len(unemp)):
    if len(str(unemp.loc[obs,'FIPS'])) == 4:
        unemp.loc[obs,'FIPS'] = f"0{unemp.loc[obs,'FIPS']}"
    else:
        unemp.loc[obs,'FIPS'] = f"{unemp.loc[obs,'FIPS']}"
        
    # 46113 was renamed from Shannon County to Oglala Lakota County, SD in May 2015.  Oglala should have FIPS 46102 but
    # 46102 is not found on the big geojson file so we reset 46102 to 46113.
    if str(unemp.loc[obs,'FIPS']) == '46102':
        unemp.loc[obs,'FIPS'] = '46113'

unemp.head()
# Out:
# Original Column Names:
# Index(['Region Name', 'Region Code', '1976 January', '1976 February',
#        '1976 March', '1976 April', '1976 May', '1976 June', '1976 July',
#        '1976 August',
#        ...
#        '2018 October', '2018 November', '2018 December', '2019 January',
#        '2019 February', '2019 March', '2019 April', '2019 May', '2019 June',
#        '2019 July'],
#       dtype='object', length=525)
# Renamed Column Names:
# ['DROP', 'FIPS', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 
200109', 'Unemp_200110', 'Unemp_200111', 'Unemp_200112', 'Unemp_200201', 'Unemp_200202', 'Unemp_200203', 'Unemp_200204', 'Unemp_200205', 'Unemp_200206', 'Unemp_200207', 'Unemp_200208', 'Unemp_200209', 'Unemp_200210', 'Unemp_200211', 'Unemp_200212', 'Unemp_200301', 'Unemp_200302', 'Unemp_200303', 'Unemp_200304', 'Unemp_200305', 'Unemp_200306', 'Unemp_200307', 'Unemp_200308', 'Unemp_200309', ...
#     FIPS  Unemp_199001  Unemp_199002  Unemp_199003  Unemp_199004  \
# 0  45001           7.0           6.8           6.8           5.5
# 1  22001           5.7           5.1           5.1           4.8
# 2  51001           8.3           8.1           6.7           5.4
# 3  16001           4.5           4.5           3.9           3.3
# 4  19001           4.0           3.7           3.3           2.5
#
#    Unemp_199005  Unemp_199006  Unemp_199007  Unemp_199008  Unemp_199009  ...  \
# 0           5.5           6.4           9.3           6.4           5.7  ...
# 1           5.6           7.1           9.6           8.1           7.3  ...
# 2           4.4           3.7           3.1           5.2           5.0  ...
# 3           3.2           3.6           3.2           3.2           3.6  ...
# 4           1.6           1.9           1.9           2.1           1.8  ...
#
#    Unemp_201811  Unemp_201812  Unemp_201901  Unemp_201902  Unemp_201903  \
# 0           3.5           3.8           4.4           3.6           3.8
# 1           4.8           4.8           5.7           4.8           4.2
# 2           3.1           3.8           5.1           4.8           4.0
# 3           2.3           2.4           3.3           2.9           2.7
# 4           1.7           2.1           2.9           2.9           2.7
#
#    Unemp_201904  Unemp_201905  Unemp_201906  Unemp_201907  In Unemp
# 0           3.3           3.9           4.2           3.8         1
# 1           3.9           4.6           5.8           5.5         1
# 2           3.3           3.3           3.2           3.1         1
# 3           2.2           2.1           2.4           2.5         1
# 4           2.0           1.9           2.1           2.1         1
#
# [5 rows x 357 columns]

# %%
xlsfile = os.path.join(raw_loc,'EducationByCounty2.xls')
xl = pd.ExcelFile(xlsfile)
edu = xl.parse('Education 1970 to 2017')
cols_in = edu.columns

print('Original Column Names:')
print(cols_in)
cols_rename = []

cols_in

for col in cols_in:
    if col == 'FIPS Code':
        cols_rename.append('FIPS')  
    elif col == 'State':
        cols_rename.append('State Abbr')  
    elif col == 'Area name':
        cols_rename.append('County Name')  

    elif col == 'Percent of adults with less than a high school diploma, 1970':
        cols_rename.append('1970_LTHS')
    elif col == 'Percent of adults with a high school diploma only, 1970':
        cols_rename.append('1970_HS')
    elif col == 'Percent of adults completing some college (1-3 years), 1970':
        cols_rename.append('1970_SomeColl')
    elif col == 'Percent of adults completing four years of college or higher, 1970':
        cols_rename.append('1970_GRAD')

    elif col == 'Percent of adults with less than a high school diploma, 1980':
        cols_rename.append('1980_LTHS')
    elif col == 'Percent of adults with a high school diploma only, 1980':
        cols_rename.append('1980_HS')
    elif col == 'Percent of adults completing some college (1-3 years), 1980':
        cols_rename.append('1980_SomeColl')
    elif col == 'Percent of adults completing four years of college or higher, 1980':
        cols_rename.append('1980_GRAD')
        
    elif col == 'Percent of adults with less than a high school diploma, 1990':
        cols_rename.append('1990_LTHS')
    elif col == 'Percent of adults with a high school diploma only, 1990':
        cols_rename.append('1990_HS')
    elif col == "Percent of adults completing some college or associate's degree, 1990":
        cols_rename.append('1990_SomeColl')
    elif col == "Percent of adults with a bachelor's degree or higher, 1990":
        cols_rename.append('1990_GRAD')        

    elif col == 'Percent of adults with less than a high school diploma, 2000':
        cols_rename.append('2000_LTHS')
    elif col == 'Percent of adults with a high school diploma only, 2000':
        cols_rename.append('2000_HS')
    elif col == "Percent of adults completing some college or associate's degree, 2000":
        cols_rename.append('2000_SomeColl')
    elif col == "Percent of adults with a bachelor's degree or higher, 2000":
        cols_rename.append('2000_GRAD')        

    elif col == 'Percent of adults with less than a high school diploma, 2013-17':
        cols_rename.append('2013_LTHS')
    elif col == 'Percent of adults with a high school diploma only, 2013-17':
        cols_rename.append('2013_HS')
    elif col == "Percent of adults completing some college or associate's degree, 2013-17":
        cols_rename.append('2013_SomeColl')
    elif col == "Percent of adults with a bachelor's degree or higher, 2013-17":
        cols_rename.append('2013_GRAD')        
        
    else:
        cols_rename.append('DROP')


print('Renamed Column Names:')
print(cols_rename)
        
edu.columns = cols_rename
edu.drop(columns =['DROP'], inplace = True) 
edu["In Edu"] = 1

# Make sure the fips codes have leading zeros.
for obs in range(0,len(edu)):
    if len(str(edu.loc[obs,'FIPS'])) == 4:
        edu.loc[obs,'FIPS'] = f"0{edu.loc[obs,'FIPS']}"
    else:
        edu.loc[obs,'FIPS'] = f"{edu.loc[obs,'FIPS']}"
        
    # FIPS code 0 for nation or last 3 digit 000 indicate state total
    if len(str(edu.loc[obs,'FIPS'])) == 1:
        edu.loc[obs,'FIPS'] = "DROP"
    elif edu.loc[obs,'FIPS'][2:5] == '000':
        edu.loc[obs,'FIPS'] = "DROP"

    # 46113 was renamed from Shannon County to Oglala Lakota County, SD in May 2015.  Oglala should have FIPS 46102 but
    # 46102 is not found on the big geojson file so we reset 46102 to 46113.
    if str(edu.loc[obs,'FIPS']) == '46102':
        edu.loc[obs,'FIPS'] = '46113'

# Drop state and national total lines
edu = edu.loc[edu["FIPS"] != 'DROP',:]

print('Final Column Names:')
print(edu.columns)

edu.head()
# Out:
# Original Column Names:
# Index(['FIPS Code', 'State', 'Area name', '2003 Rural-urban Continuum Code',
#        '2003 Urban Influence Code', '2013 Rural-urban Continuum Code',
#        '2013 Urban Influence Code', 'Less than a high school diploma, 1970',
#        'High school diploma only, 1970', 'Some college (1-3 years), 1970',
#        'Four years of college or higher, 1970',
#        'Percent of adults with less than a high school diploma, 1970',
#        'Percent of adults with a high school diploma only, 1970',
#        'Percent of adults completing some college (1-3 years), 1970',
#        'Percent of adults completing four years of college or higher, 1970',
#        'Less than a high school diploma, 1980',
#        'High school diploma only, 1980', 'Some college (1-3 years), 1980',
#        'Four years of college or higher, 1980',
#        'Percent of adults with less than a high school diploma, 1980',
#        'Percent of adults with a high school diploma only, 1980',
#        'Percent of adults completing some college (1-3 years), 1980',
#        'Percent of adults completing four years of college or higher, 1980',
#        'Less than a high school diploma, 1990',
#        'High school diploma only, 1990',
#        'Some college or associate's degree, 1990',
#        'Bachelor's degree or higher, 1990',
#        'Percent of adults with less than a high school diploma, 1990',
#        'Percent of adults with a high school diploma only, 1990',
#        'Percent of adults completing some college or associate's degree, 1990',
#        'Percent of adults with a bachelor's degree or higher, 1990',
#        'Less than a high school diploma, 2000',
#        'High school diploma only, 2000',
#        'Some college or associate's degree, 2000',
#        'Bachelor's degree or higher, 2000',
#        'Percent of adults with less than a high school diploma, 2000',
#        'Percent of adults with a high school diploma only, 2000',
#        'Percent of adults completing some college or associate's degree, 2000',
#        'Percent of adults with a bachelor's degree or higher, 2000',
#        'Less than a high school diploma, 2013-17',
#        'High school diploma only, 2013-17',
#        'Some college or associate's degree, 2013-17',
#        'Bachelor's degree or higher, 2013-17',
#        'Percent of adults with less than a high school diploma, 2013-17',
#        'Percent of adults with a high school diploma only, 2013-17',
#        'Percent of adults completing some college or associate's degree, 2013-17',
#        'Percent of adults with a bachelor's degree or higher, 2013-17'],
#       dtype='object')
# Renamed Column Names:
# ['FIPS', 'State Abbr', 'County Name', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', 'DROP', '1970_LTHS', '1970_HS', '1970_SomeColl', '1970_GRAD', 'DROP', 'DROP', 'DROP', 'DROP', '1980_LTHS', '1980_HS', '1980_SomeColl', '1980_GRAD', 'DROP', 'DROP', 'DROP', 'DROP', '1990_LTHS', '1990_HS', '1990_SomeColl', '1990_GRAD', 'DROP', 'DROP', 'DROP', 'DROP', '2000_LTHS', '2000_HS', '2000_SomeColl', '2000_GRAD', 'DROP', 'DROP', 'DROP', 'DROP', '2013_LTHS', '2013_HS', '2013_SomeColl', '2013_GRAD']
# Final Column Names:
# Index(['FIPS', 'State Abbr', 'County Name', '1970_LTHS', '1970_HS',
#        '1970_SomeColl', '1970_GRAD', '1980_LTHS', '1980_HS', '1980_SomeColl',
#        '1980_GRAD', '1990_LTHS', '1990_HS', '1990_SomeColl', '1990_GRAD',
#        '2000_LTHS', '2000_HS', '2000_SomeColl', '2000_GRAD', '2013_LTHS',
#        '2013_HS', '2013_SomeColl', '2013_GRAD', 'In Edu'],
#       dtype='object')
#     FIPS State Abbr     County Name  1970_LTHS  1970_HS  1970_SomeColl  \
# 2  01001         AL  Autauga County       54.8     31.1            7.7
# 3  01003         AL  Baldwin County       59.4     26.7            7.4
# 4  01005         AL  Barbour County       68.8     19.0            4.9
# 5  01007         AL     Bibb County       73.1     19.4            3.3
# 6  01009         AL   Blount County       70.5     22.7            4.1
#
#    1970_GRAD  1980_LTHS  1980_HS  1980_SomeColl  ...  1990_GRAD  2000_LTHS  \
# 2        6.4       40.6     35.2           12.1  ...       14.5       21.3
# 3        6.5       39.7     33.7           14.5  ...       16.8       18.0
# 4        7.3       55.1     26.1            9.7  ...       11.8       35.3
# 5        4.2       59.5     29.6            6.1  ...        4.7       36.8
# 6        2.7       53.9     32.4            8.4  ...        7.0       29.6
#
#    2000_HS  2000_SomeColl  2000_GRAD  2013_LTHS  2013_HS  2013_SomeColl  \
# 2     33.8           26.9       18.0       12.3     33.6           29.1
# 3     29.6           29.3       23.1        9.8     27.8           31.7
# 4     32.4           21.3       10.9       26.9     35.5           25.5
# 5     35.7           20.4        7.1       17.9     43.9           25.0
# 6     36.0           24.8        9.6       20.2     32.3           34.4
#
#    2013_GRAD  In Edu
# 2       25.0       1
# 3       30.7       1
# 4       12.0       1
# 5       13.2       1
# 6       13.1       1
#
# [5 rows x 24 columns]

# %%
xlsfile = os.path.join(raw_loc,'GDPByCounty2.csv')
gdp = pd.read_csv(xlsfile)
gdp.head()
# Out:
#     FIPS Countyname Postal  LineCode                             IndustryName  \
# 0  01001    Autauga     AL       1.0                           All Industries
# 1  01001    Autauga     AL       2.0       Private goods-producing industries
# 2  01001    Autauga     AL       3.0    Private services-providing industries
# 3  01001    Autauga     AL       4.0    Government and government enterprises
# 4  01003    Baldwin     AL       1.0                           All Industries
#
#    2013  2014  2015
# 0  -4.4  -0.7   7.6
# 1   4.4   3.9   4.7
# 2  -7.2  -2.2   9.9
# 3  -4.0  -1.5   0.3
# 4  11.1   0.5  -4.3

# %%
# Keep only the all-industries line
gdp = gdp.loc[gdp["IndustryName"] == 'All Industries',:]

cols_in = gdp.columns
cols_rename = []
print('Original Column Names:')
print(cols_in)

for col in cols_in:
    
    if col == 'FIPS':
        cols_rename.append('FIPS')
    elif col == 'Countyname' :
        cols_rename.append("CountyNameGDP")
    elif col == '2013' :
        cols_rename.append("GDP_Change_2012_2013")
    elif col == '2014' :
        cols_rename.append("GDP_Change_2013_2014")
    elif col == '2015' :
        cols_rename.append("GDP_Change_2014_2015")
    else:
        cols_rename.append('DROP')
        
print('Renamed Column Names:')
print(cols_rename)

gdp.columns = cols_rename
gdp.drop(columns =['DROP'], inplace = True) 
gdp["In GDP"] = 1
gdp['CombinedCounty'] = 0

# Make sure the fips codes have leading zeros.
for row, rowvals in gdp.iterrows():
     
    if rowvals[1].find('+') > -1:
        gdp.loc[row,'CombinedCounty'] = 1

print('Final Column Names:')
print(gdp.columns)


gdp.head()
# Out:
# Original Column Names:
# Index(['FIPS', 'Countyname', 'Postal', 'LineCode', 'IndustryName', '2013',
#        '2014', '2015'],
#       dtype='object')
# Renamed Column Names:
# ['FIPS', 'CountyNameGDP', 'DROP', 'DROP', 'DROP', 'GDP_Change_2012_2013', 'GDP_Change_2013_2014', 'GDP_Change_2014_2015']
# Final Column Names:
# Index(['FIPS', 'CountyNameGDP', 'GDP_Change_2012_2013', 'GDP_Change_2013_2014',
#        'GDP_Change_2014_2015', 'In GDP', 'CombinedCounty'],
#       dtype='object')
#      FIPS CountyNameGDP GDP_Change_2012_2013 GDP_Change_2013_2014  \
# 0   01001       Autauga                 -4.4                 -0.7
# 4   01003       Baldwin                 11.1                  0.5
# 8   01005       Barbour                  7.5                 -3.5
# 12  01007          Bibb                  5.7                 -2.8
# 16  01009        Blount                  8.1                 -3.3
#
#    GDP_Change_2014_2015  In GDP  CombinedCounty
# 0                   7.6       1               0
# 4                  -4.3       1               0
# 8                   6.8       1               0
# 12                 -4.5       1               0
# 16                 17.7       1               0

# %%
# Output the combination counties so we can separate them, look up county codes and append them back on
combos = gdp.loc[gdp['CombinedCounty']==1,:]
countycheck_csv = os.path.join(raw_loc,'combined_counties.csv')
countycheck_out = combos.to_csv(countycheck_csv,index=False)
combos.head()
# Out:
#         FIPS                   CountyNameGDP GDP_Change_2012_2013  \
# 2196   15901                  Maui + Kalawao                  0.6
# 11604  51901     Albemarle + Charlottesville                 -0.4
# 11608  51903           Alleghany + Covington                  5.5
# 11612  51907  Augusta, Staunton + Waynesboro                  2.3
# 11616  51911            Campbell + Lynchburg                 -1.4
#
#       GDP_Change_2013_2014 GDP_Change_2014_2015  In GDP  CombinedCounty
# 2196                   2.2                  3.4       1               1
# 11604                  2.2                  2.1       1               1
# 11608                 -5.0                  6.5       1               1
# 11612                  0.5                  4.0       1               1
# 11616                 -0.2                 -0.3       1               1

# %%
# pull in the spreadsheet with the combined counties separated out
combosfixed = pd.read_csv(os.path.join(raw_loc,'combined_counties_separated.csv'))
combosfixed['FIPS'] = combosfixed.FIPS.astype(object)
combosfixed.dtypes
# Out:
# FIPS                     object
# CountyNameGDP            object
# GDP_Change_2012_2013    float64
# GDP_Change_2013_2014    float64
# GDP_Change_2014_2015    float64
# In GDP                    int64
# CombinedCounty            int64
# dtype: object

# %%
len_b4 = len(gdp)
gdp = gdp.loc[gdp['CombinedCounty']==0,:]
len_during = len(gdp)
gdp = pd.concat([gdp,combosfixed])
len_after = len(gdp)

print("Added separate entries for combined counties in GDP data")
print(f"Length before removing combinations: {len_b4}")
print(f"Length after removing combinations: {len_during}")
print(f"Length after adding fixed combinations: {len_after}")

gdp.head()
# Out:
# Added separate entries for combined counties in GDP data
# Length before removing combinations: 3113
# Length after removing combinations: 3089
# Length after adding fixed combinations: 3142
#      FIPS CountyNameGDP GDP_Change_2012_2013 GDP_Change_2013_2014  \
# 0   01001       Autauga                 -4.4                 -0.7
# 4   01003       Baldwin                 11.1                  0.5
# 8   01005       Barbour                  7.5                 -3.5
# 12  01007          Bibb                  5.7                 -2.8
# 16  01009        Blount                  8.1                 -3.3
#
#    GDP_Change_2014_2015  In GDP  CombinedCounty
# 0                   7.6       1               0
# 4                  -4.3       1               0
# 8                   6.8       1               0
# 12                 -4.5       1               0
# 16                 17.7       1               0

# %%
check_gdp = gdp.loc[gdp["CombinedCounty"]==1,:]
check_gdp.head(50)
# Out:
#      FIPS     CountyNameGDP GDP_Change_2012_2013 GDP_Change_2013_2014  \
# 0   15009              Maui                  0.6                  2.2
# 1   15005           Kalawao                  0.6                  2.2
# 2   51003         Albemarle                 -0.4                  2.2
# 3   51540   Charlottesville                 -0.4                  2.2
# 4   51005         Alleghany                  5.5                   -5
# 5   51580         Covington                  5.5                   -5
# 6   51015           Augusta                  2.3                  0.5
# 7   51790          Staunton                  2.3                  0.5
# 8   51820        Waynesboro                  2.3                  0.5
# 9   51031          Campbell                 -1.4                 -0.2
# 10  51680         Lynchburg                 -1.4                 -0.2
# 11  51035           Carroll                    1                 -0.4
# 12  51640             Galax                    1                 -0.4
# 13  51053         Dinwiddie                 -0.5                 -2.6
# 14  51570  Colonial Heights                 -0.5                 -2.6
# 15  51730        Petersburg                 -0.5                 -2.6
# 16  51059           Fairfax                  0.1                  0.6
# 17  51600      Fairfax City                  0.1                  0.6
# 18  51610      Falls Church                  0.1                  0.6
# 19  51069         Frederick                 -3.1                 -1.3
# 20  51840        Winchester                 -3.1                 -1.3
# 21  51081       Greensville                   15                  6.1
# 22  51595           Emporia                   15                  6.1
# 23  51089             Henry                   -1                  1.5
# 24  51690      Martinsville                   -1                  1.5
# 25  51095        James City                 -2.8                 -2.9
# 26  51830      Williamsburg                 -2.8                 -2.9
# 27  51121        Montgomery                  5.8                  4.8
# 28  51750           Radford                  5.8                  4.8
# 29  51143      Pittsylvania                 -0.4                 -2.8
# 30  51590          Danville                 -0.4                 -2.8
# 31  51149     Prince George                 -1.7                 -5.3
# 32  51670          Hopewell                 -1.7                 -5.3
# 33  51153    Prince William                  1.2                  2.3
# 34  51683          Manassas                  1.2                  2.3
# 35  51685     Manassas Park                  1.2                  2.3
# 36  51161    Roanoke County                  2.8                  0.9
# 37  51775             Salem                  2.8                  0.9
# 38  51163        Rockbridge                 -6.9                 -0.3
# 39  51530       Buena Vista                 -6.9                 -0.3
# 40  51678         Lexington                 -6.9                 -0.3
# 41  51165        Rockingham                  0.9                 -3.8
# 42  51660      Harrisonburg                  0.9                 -3.8
# 43  51175       Southampton                 -4.1                 -1.2
# 44  51620          Franklin                 -4.1                 -1.2
# 45  51177      Spotsylvania                  4.4                 -0.4
# 46  51630    Fredericksburg                  4.4                 -0.4
# 47  51191        Washington                 -6.9                -13.1
# 48  51520           Bristol                 -6.9                -13.1
# 49  51195              Wise                 -8.6                  0.9
#
#    GDP_Change_2014_2015  In GDP  CombinedCounty
# 0                   3.4       1               1
# 1                   3.4       1               1
# 2                   2.1       1               1
# 3                   2.1       1               1
# 4                   6.5       1               1
# 5                   6.5       1               1
# 6                     4       1               1
# 7                     4       1               1
# 8                     4       1               1
# 9                  -0.3       1               1
# 10                 -0.3       1               1
# 11                  1.6       1               1
# 12                  1.6       1               1
# 13                    4       1               1
# 14                    4       1               1
# 15                    4       1               1
# 16                  1.4       1               1
# 17                  1.4       1               1
# 18                  1.4       1               1
# 19                    5       1               1
# 20                    5       1               1
# 21                   -2       1               1
# 22                   -2       1               1
# 23                    9       1               1
# 24                    9       1               1
# 25                 -1.3       1               1
# 26                 -1.3       1               1
# 27                  6.1       1               1
# 28                  6.1       1               1
# 29                 -2.2       1               1
# 30                 -2.2       1               1
# 31                  0.1       1               1
# 32                  0.1       1               1
# 33                  0.5       1               1
# 34                  0.5       1               1
# 35                  0.5       1               1
# 36                  2.3       1               1
# 37                  2.3       1               1
# 38                 -0.8       1               1
# 39                 -0.8       1               1
# 40                 -0.8       1               1
# 41                 -1.4       1               1
# 42                 -1.4       1               1
# 43                  2.9       1               1
# 44                  2.9       1               1
# 45                  6.1       1               1
# 46                  6.1       1               1
# 47                 -2.4       1               1
# 48                 -2.4       1               1
# 49                 -3.5       1               1

# %%
all_county_info = pd.merge(pcpi,\
                  pd.merge(unemp,\
                  pd.merge(edu,gdp,on='FIPS',how='outer'),on='FIPS',how='outer'),on='FIPS',how='outer')

# Clean up county names where necessary
for obs,row in all_county_info.iterrows():

    if str(all_county_info.loc[obs,'FIPS']) == '02270':
        all_county_info.loc[obs,'County Name'] = 'Wade Hampton'
        all_county_info.loc[obs,'State Abbr'] = 'AK'
        
    if all_county_info.loc[obs,'CombinedCounty'] == 1:
        
        if str(all_county_info.loc[obs,'FIPS'])[0:2] == '15':
            all_county_info.loc[obs,'State Abbr'] = "HI"
        elif str(all_county_info.loc[obs,'FIPS'])[0:2] == '51':
            all_county_info.loc[obs,'State Abbr'] = "VA"
        all_county_info.loc[obs,'County Name'] = all_county_info.loc[obs,'CountyNameGDP'] 
        

all_county_info.head()
# Out:
#     FIPS  PCPI_2001  PCPI_2002  PCPI_2003  PCPI_2004  PCPI_2005  PCPI_2006  \
# 0  45001    23201.0    21528.0    20359.0    21756.0    22375.0    23410.0
# 1  22001    21019.0    21565.0    22264.0    22569.0    24134.0    25908.0
# 2  51001    21119.0    22156.0    23971.0    25337.0    26630.0    27828.0
# 3  16001    33528.0    34195.0    34676.0    36657.0    37544.0    40471.0
# 4  29001    21125.0    21065.0    21269.0    22361.0    23133.0    24114.0
#
#    PCPI_2007  PCPI_2008  PCPI_2009  ...  2013_HS  2013_SomeColl  2013_GRAD  \
# 0    24311.0    25712.0    25702.0  ...     34.3           29.5       14.7
# 1    27751.0    31483.0    31140.0  ...     40.8           24.7       12.2
# 2    29914.0    32114.0    32607.0  ...     39.0           23.6       19.6
# 3    40561.0    39479.0    37727.0  ...     22.4           34.7       37.6
# 4    25295.0    26552.0    27800.0  ...     35.6           23.9       31.0
#
#    In Edu  CountyNameGDP  GDP_Change_2012_2013  GDP_Change_2013_2014  \
# 0     1.0      Abbeville                  -2.5                  -4.7
# 1     1.0         Acadia                  -6.9                  -0.5
# 2     1.0       Accomack                   2.2                  -1.0
# 3     1.0            Ada                   5.9                   3.9
# 4     1.0          Adair                   1.7                   1.1
#
#    GDP_Change_2014_2015  In GDP  CombinedCounty
# 0                  -0.8     1.0             0.0
# 1                  -0.3     1.0             0.0
# 2                   2.2     1.0             0.0
# 3                   1.3     1.0             0.0
# 4                   5.7     1.0             0.0
#
# [5 rows x 420 columns]

# %%
# Find places where the county and state name are blank.
data2check = all_county_info.loc[all_county_info["State Abbr"].isnull() == True,['FIPS','FIPS Out','In PCPI',\
                                                                                 'In Edu','In GDP','In Unemp','State Abbr',\
                                                                                 'County Name','CountyNameGDP',\
                                                                                 'GDP_Change_2012_2013', \
                                                                                 'GDP_Change_2013_2014',\
                                                                                 'GDP_Change_2014_2015', ]]
print(len(data2check))
data2check.head(30)
# Out:
# 0
# C:\Users\laslo\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexing.py:1494: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)
# Empty DataFrame
# Columns: [FIPS, FIPS Out, In PCPI, In Edu, In GDP, In Unemp, State Abbr, County Name, CountyNameGDP, GDP_Change_2012_2013, GDP_Change_2013_2014, GDP_Change_2014_2015]
# Index: []

# %%
data2check2 = all_county_info.loc[all_county_info['In PCPI'] + all_county_info['In GDP'] + \
                                  all_county_info['In Edu'] + all_county_info['In Unemp'] != 4,\
                                  ['FIPS','In PCPI','In Edu','In Unemp','In GDP','State Abbr','County Name']]
print(f"There are {len(data2check2)} counties that are not in all four input datasets")
data2check2.head()
# Out:
# There are 200 counties that are not in all four input datasets
#        FIPS  In PCPI  In Edu  In Unemp  In GDP State Abbr  \
# 278   08014      1.0     1.0       NaN     1.0         CO
# 1511  02270      1.0     NaN       1.0     NaN         AK
# 2204  02195      1.0     1.0       NaN     1.0         AK
# 2575  02230      1.0     1.0       NaN     1.0         AK
# 3052  02275      1.0     1.0       NaN     1.0         AK
#
#                     County Name
# 278           Broomfield County
# 1511               Wade Hampton
# 2204     Petersburg Census Area
# 2575       Skagway Municipality
# 3052  Wrangell City and Borough

# %%
county_csv = os.path.join(clean_loc,'CountyLevelData.csv')
county_out = all_county_info.to_csv(county_csv,index=False)

# %%
vnames = all_county_info.columns.tolist()

# %%
# Create a dictionary to hold state and county fips codes
# fipsdict has the state and county associated with each fips code
fipsdict = {}

# Go through the list of counties in our data and make sure each is 
# represented in the fipsdict. This will allow us to have FIPS, STATEFP,
# and COUNTYFP on each geojson file.
for row, rowvals in all_county_info.iterrows():
    
    # pull information from dataframe into temporary variables
    FIPS = str(rowvals[0])
    STATEFP = str(FIPS)[0:2]
    COUNTYFP = str(FIPS)[2:5]
    
    # If we have not yet seen this FIPS code, add it to the dictionary
    if FIPS not in fipsdict:
        fipsdict[FIPS]={}
 
    # Append the data for this county to its entry in the dictionary
    fipsdict[FIPS]={
        "STATEFP": STATEFP,
        "COUNTYFP": COUNTYFP}
    
fipsdict
# Out:
# {'45001': {'STATEFP': '45', 'COUNTYFP': '001'},
#  '22001': {'STATEFP': '22', 'COUNTYFP': '001'},
#  '51001': {'STATEFP': '51', 'COUNTYFP': '001'},
#  '16001': {'STATEFP': '16', 'COUNTYFP': '001'},
#  '29001': {'STATEFP': '29', 'COUNTYFP': '001'},
#  '40001': {'STATEFP': '40', 'COUNTYFP': '001'},
#  '19001': {'STATEFP': '19', 'COUNTYFP': '001'},
#  '21001': {'STATEFP': '21', 'COUNTYFP': '001'},
#  '53001': {'STATEFP': '53', 'COUNTYFP': '001'},
#  '39001': {'STATEFP': '39', 'COUNTYFP': '001'},
#  '42001': {'STATEFP': '42', 'COUNTYFP': '001'},
#  '16003': {'STATEFP': '16', 'COUNTYFP': '003'},
#  '28001': {'STATEFP': '28', 'COUNTYFP': '001'},
#  '38001': {'STATEFP': '38', 'COUNTYFP': '001'},
#  '19003': {'STATEFP': '19', 'COUNTYFP': '003'},
#  '31001': {'STATEFP': '31', 'COUNTYFP': '001'},
#  '18001': {'STATEFP': '18', 'COUNTYFP': '001'},
#  '55001': {'STATEFP': '55', 'COUNTYFP': '001'},
#  '05049': {'STATEFP': '05', 'COUNTYFP': '049'},
#  '36035': {'STATEFP': '36', 'COUNTYFP': '035'},
#  '21075': {'STATEFP': '21', 'COUNTYFP': '075'},
#  '13121': {'STATEFP': '13', 'COUNTYFP': '121'},
#  '39051': {'STATEFP': '39', 'COUNTYFP': '051'},
#  '42057': {'STATEFP': '42', 'COUNTYFP': '057'},
#  '17057': {'STATEFP': '17', 'COUNTYFP': '057'},
#  '18049': {'STATEFP': '18', 'COUNTYFP': '049'},
#  '31065': {'STATEFP': '31', 'COUNTYFP': '065'},
#  '12039': {'STATEFP': '12', 'COUNTYFP': '039'},
#  '31067': {'STATEFP': '31', 'COUNTYFP': '067'},
#  '48165': {'STATEFP': '48', 'COUNTYFP': '165'},
#  '30031': {'STATEFP': '30', 'COUNTYFP': '031'},
#  '21077': {'STATEFP': '21', 'COUNTYFP': '077'},
#  '17059': {'STATEFP': '17', 'COUNTYFP': '059'},
#  '39053': {'STATEFP': '39', 'COUNTYFP': '053'},
#  '48167': {'STATEFP': '48', 'COUNTYFP': '167'},
#  '31069': {'STATEFP': '31', 'COUNTYFP': '069'},
#  '08045': {'STATEFP': '08', 'COUNTYFP': '045'},
#  '31071': {'STATEFP': '31', 'COUNTYFP': '071'},
#  '53023': {'STATEFP': '53', 'COUNTYFP': '023'},
#  '49017': {'STATEFP': '49', 'COUNTYFP': '017'},
#  '30033': {'STATEFP': '30', 'COUNTYFP': '033'},
#  '40047': {'STATEFP': '40', 'COUNTYFP': '047'},
#  '05051': {'STATEFP': '05', 'COUNTYFP': '051'},
#  '21079': {'STATEFP': '21', 'COUNTYFP': '079'},
#  '24023': {'STATEFP': '24', 'COUNTYFP': '023'},
#  '40049': {'STATEFP': '40', 'COUNTYFP': '049'},
#  ...}

# %%
# Create the initial geojson file by pulling records from the big/historical geojson
# and keeping only records that apply to that year.
def create_yearly_geojson(year):
    
    # create a reference to the output file
    outfile = os.path.join(clean_loc,f'FinalGeoFile{year}.json')

    # Create a numeric variable of the year to check against
    year2check = year
    
    # Create a blank list of the features we will keep
    features = []
    
    # Open up the existing geojson file and read it into the empty geojson dictionary created above.
    # While reading it in, pull the matching state and county fips from the data2add dictionary so we can add the unemployment info to the geojson.
    with open(big_geojson, 'r') as f:
        temp = json.load(f)
        
        for feature in temp['features']:
            
            featureProperties = feature['properties']
            FIPS = featureProperties['FIPS']
            
            start_year = int(featureProperties["START_DATE"][0:4])
            end_year = int(featureProperties["END_DATE"][0:4])
            
            # Add the state and county fips codes so this json will look
            # like the ones for later years from Census
            featureData = fipsdict.get(FIPS, {})
            for key in featureData.keys():
                featureProperties[key] = featureData[key]
        
            if start_year <= year2check and year2check <= end_year:
                features.append(feature)
                
    last_feature = len(features)-1
                
    # Output a new geojson file specific to this year.
    with open(outfile,'w') as f:
        f.write('{"type":"FeatureCollection","features": [')
        for feature in features:
            json.dump(feature, f)
            if features.index(feature) < last_feature:
                f.write(',')
        f.write(']}')

create_yearly_geojson(1970)
create_yearly_geojson(1980)
for year in range(1990,2001):
    create_yearly_geojson(year)

# %%
def create_final_geojson(year):
    
    year2check = year
    pyear = year - 1

    # for years greater than 2000 we also need the two digit year
    yr = str(year2check)[2:4]
    
    # create a reference to the input geojson file. Different years have different files/formats
    if year2check <= 2000:
        infile = os.path.join(clean_loc,f'FinalGeoFile{year}.json')
    elif year2check <= 2009:
        infile = os.path.join(clean_loc,f'FinalGeoFile2000.json')
    #elif year2check <= 2009:
    #    infile = os.path.join(raw_loc,f'tl_{year}_us_county00.json')
    #elif year2check == 2010:
    #    infile = os.path.join(raw_loc,f'tl_2010_us_county10.json')
    #elif year2check <= 2012:
    #    infile = os.path.join(raw_loc,f'tl_{year}_us_county.json')
    elif year2check <= 2013:
        infile = os.path.join(raw_loc,f'cb_2013_us_county_20m.json')
    elif year2check <= 2018:
        infile = os.path.join(raw_loc,f'cb_{year}_us_county_20m.json')
    #elif year2check <= 2019:
    #    infile = os.path.join(raw_loc,f'tl_{year}_us_county.json')
    else:
        infile = os.path.join(raw_loc,f'tl_2018_us_county.json')
    
    # create a reference to the output file
    outfile = os.path.join(clean_loc,f'FinalGeoFile{year}.json')
    
    print(f"infile = {infile}")
    print(f"outfile = {outfile}")
    
    # Create a blank dictionary to hold the data we will be tacking onto the geojson file
    data2add = {}

    # Loop through the dataframe and add information to the data2add dictionary. 
    # We will use this to put these values into the geojson.
    for row, rowvals in all_county_info.iterrows():
        
        # pull information from dataframe into temporary variables
        FIPS = rowvals[0]   
        STATEFP = str(rowvals[0])[0:2]
        COUNTYFP = str(rowvals[0])[2:5]
        StateAbbr = rowvals[vnames.index('State Abbr')]  
        CountyName = rowvals[vnames.index('County Name')]
        
        # pull monthly unemployment for this year, if it exists for this year
        if f'Unemp_{year}01' in vnames:
            temp01 = rowvals[vnames.index(f'Unemp_{year}01')]
        else:
            temp01 = -1
        if f'Unemp_{year}02' in vnames:
            temp02 = rowvals[vnames.index(f'Unemp_{year}02')]
        else:
            temp02 = -1
        if f'Unemp_{year}03' in vnames:
            temp03 = rowvals[vnames.index(f'Unemp_{year}03')]
        else:
            temp03 = -1
        if f'Unemp_{year}04' in vnames:
            temp04 = rowvals[vnames.index(f'Unemp_{year}04')]
        else:
            temp04 = -1
        if f'Unemp_{year}05' in vnames:
            temp05 = rowvals[vnames.index(f'Unemp_{year}05')]
        else:
            temp05 = -1
        if f'Unemp_{year}06' in vnames:
            temp06 = rowvals[vnames.index(f'Unemp_{year}06')]
        else:
            temp06 = -1
        if f'Unemp_{year}07' in vnames:
            temp07 = rowvals[vnames.index(f'Unemp_{year}07')]
        else:
            temp07 = -1
        if f'Unemp_{year}08' in vnames:
            temp08 = rowvals[vnames.index(f'Unemp_{year}08')]
        else:
            temp08 = -1
        if f'Unemp_{year}09' in vnames:
            temp09 = rowvals[vnames.index(f'Unemp_{year}09')]
        else:
            temp09 = -1
        if f'Unemp_{year}10' in vnames:
            temp10 = rowvals[vnames.index(f'Unemp_{year}10')]
        else:
            temp10 = -1
        if f'Unemp_{year}11' in vnames:
            temp11 = rowvals[vnames.index(f'Unemp_{year}11')]
        else:
            temp11 = -1
        if f'Unemp_{year}12' in vnames:
            temp12 = rowvals[vnames.index(f'Unemp_{year}12')]
        else:
            temp12 = -1

        # Pull per-capital personal income, if it exists for this year
        if f'PCPI_{pyear}' in vnames and f'PCPI_{year}' in vnames:
            PCPI = rowvals[vnames.index(f'PCPI_{year}')]
            PCPI_previous = rowvals[vnames.index(f'PCPI_{pyear}')]
            PCPI_PctChange = rowvals[vnames.index(f'PCPI_PctChange_{year}')]
        else:
            PCPI = -1
            PCPI_previous = -1
            PCPI_PctChange = -1
            
        # Pull gdp, if it exists for this year
        if year2check == 2013:
            GDP = rowvals[vnames.index('GDP_Change_2012_2013')]
        elif year2check == 2014:
            GDP = rowvals[vnames.index('GDP_Change_2013_2014')]
        elif year2check == 2015:
            GDP = rowvals[vnames.index('GDP_Change_2014_2015')]
        else:
            GDP = -1

        # Pull eductional attainment, if it exists for this year
        if year2check in (1970, 1980, 1990, 2000, 2013):
            LTHS = rowvals[vnames.index(f'{year}_LTHS')]
            HS = rowvals[vnames.index(f'{year}_HS')]
            SomeColl = rowvals[vnames.index(f'{year}_SomeColl')]
            GRAD = rowvals[vnames.index(f'{year}_GRAD')]
        else:
            LTHS = -1
            HS = -1
            SomeColl = -1
            GRAD = -1
            
        # Check to see if this state/county has already been added to the dictionary.
        # If not, then add an entry for it.
        if FIPS not in data2add:
            data2add[FIPS]={}
        
        # Append the data for this county to its entry in the dictionary
        data2add[FIPS]={
            "StateAbbr": StateAbbr,
            "CountyName": CountyName,
            f"Unemp_{year}01" : f"{temp01}",
            f"Unemp_{year}02" : f"{temp02}",
            f"Unemp_{year}03" : f"{temp03}",
            f"Unemp_{year}04" : f"{temp04}",
            f"Unemp_{year}05" : f"{temp05}",
            f"Unemp_{year}06" : f"{temp06}",
            f"Unemp_{year}07" : f"{temp07}",
            f"Unemp_{year}08" : f"{temp08}",
            f"Unemp_{year}09" : f"{temp09}",
            f"Unemp_{year}10" : f"{temp10}",
            f"Unemp_{year}11" : f"{temp11}",
            f"Unemp_{year}12" : f"{temp12}",
            f"PCPI_Current": f"{PCPI}",
            f"PCPI_Previous": f"{PCPI_previous}",
            f"PCPI_PctChange": f"{PCPI_PctChange}",
            f"GDP_change_{year}": f"{GDP}",
            "LTHS" : f"{LTHS}",
            "HS" : f"{HS}",
            "SomeColl" : f"{SomeColl}",
            "GRAD" : f"{GRAD}"
        }
    
    #print(data2add)
            
    # Create a blank geojson for the final result
    geojson = {}
    
    # Open up the existing geojson file and read it into the empty geojson dictionary created above.
    # While reading it in, pull the matching state and county fips from the data2add dictionary so we can add the unemployment info to the geojson.
    with open(infile, 'r') as f:
        geojson = json.load(f)
        for feature in geojson['features']:
            featureProperties = feature['properties']
            
            if year2check <= 2007:
                FIPS = featureProperties['FIPS']
                STATEFP = str(FIPS)[0:2]
                COUNTYFP = str(FIPS)[2:5]
            elif year2check <= 2009:
                STATEFP = featureProperties['STATEFP00']
                COUNTYFP = featureProperties['COUNTYFP00']
                FIPS = STATEFP + COUNTYFP
            elif year2check == 2010:
                STATEFP = featureProperties['STATEFP10']
                COUNTYFP = featureProperties['COUNTYFP10']
                FIPS = STATEFP + COUNTYFP
            elif year2check <= 2020:
                STATEFP = featureProperties['STATEFP']
                COUNTYFP = featureProperties['COUNTYFP']
                FIPS = STATEFP + COUNTYFP

            featureData = data2add.get(FIPS, {})
            for key in featureData.keys():
                featureProperties[key] = featureData[key]

    # Output this updated geojson.
    with open(outfile, 'w') as f:
        json.dump(geojson, f)
         
create_final_geojson(1970)
create_final_geojson(1980)
for year in range(1990,2020):
    create_final_geojson(year)
# Out:
# infile = static\assets\geojson\FinalGeoFile1970.json
# outfile = static\assets\geojson\FinalGeoFile1970.json
# infile = static\assets\geojson\FinalGeoFile1980.json
# outfile = static\assets\geojson\FinalGeoFile1980.json
# infile = static\assets\geojson\FinalGeoFile1990.json
# outfile = static\assets\geojson\FinalGeoFile1990.json
# infile = static\assets\geojson\FinalGeoFile1991.json
# outfile = static\assets\geojson\FinalGeoFile1991.json
# infile = static\assets\geojson\FinalGeoFile1992.json
# outfile = static\assets\geojson\FinalGeoFile1992.json
# infile = static\assets\geojson\FinalGeoFile1993.json
# outfile = static\assets\geojson\FinalGeoFile1993.json
# infile = static\assets\geojson\FinalGeoFile1994.json
# outfile = static\assets\geojson\FinalGeoFile1994.json
# infile = static\assets\geojson\FinalGeoFile1995.json
# outfile = static\assets\geojson\FinalGeoFile1995.json
# infile = static\assets\geojson\FinalGeoFile1996.json
# outfile = static\assets\geojson\FinalGeoFile1996.json
# infile = static\assets\geojson\FinalGeoFile1997.json
# outfile = static\assets\geojson\FinalGeoFile1997.json
# infile = static\assets\geojson\FinalGeoFile1998.json
# outfile = static\assets\geojson\FinalGeoFile1998.json
# infile = static\assets\geojson\FinalGeoFile1999.json
# outfile = static\assets\geojson\FinalGeoFile1999.json
# infile = static\assets\geojson\FinalGeoFile2000.json
# outfile = static\assets\geojson\FinalGeoFile2000.json
# infile = static\assets\geojson\FinalGeoFile2000.json
# outfile = static\assets\geojson\FinalGeoFile2001.json
# infile = static\assets\geojson\FinalGeoFile2000.json
# outfile = static\assets\geojson\FinalGeoFile2002.json
# infile = static\assets\geojson\FinalGeoFile2000.json
# outfile = static\assets\geojson\FinalGeoFile2003.json
# infile = static\assets\geojson\FinalGeoFile2000.json
# outfile = static\assets\geojson\FinalGeoFile2004.json
# infile = static\assets\geojson\FinalGeoFile2000.json
# outfile = static\assets\geojson\FinalGeoFile2005.json
# infile = static\assets\geojson\FinalGeoFile2000.json
# outfile = static\assets\geojson\FinalGeoFile2006.json
# infile = static\assets\geojson\FinalGeoFile2000.json
# outfile = static\assets\geojson\FinalGeoFile2007.json
# infile = RawData\tl_2008_us_county00.json
# outfile = static\assets\geojson\FinalGeoFile2008.json
# infile = RawData\tl_2009_us_county00.json
# outfile = static\assets\geojson\FinalGeoFile2009.json
# infile = RawData\tl_2010_us_county10.json
# outfile = static\assets\geojson\FinalGeoFile2010.json
# infile = RawData\tl_2011_us_county.json
# outfile = static\assets\geojson\FinalGeoFile2011.json
# infile = RawData\tl_2012_us_county.json
# outfile = static\assets\geojson\FinalGeoFile2012.json
# infile = RawData\cb_2013_us_county_20m.json
# outfile = static\assets\geojson\FinalGeoFile2013.json
# infile = RawData\cb_2014_us_county_20m.json
# outfile = static\assets\geojson\FinalGeoFile2014.json
# infile = RawData\cb_2015_us_county_20m.json
# outfile = static\assets\geojson\FinalGeoFile2015.json
# infile = RawData\cb_2016_us_county_20m.json
# outfile = static\assets\geojson\FinalGeoFile2016.json
# infile = RawData\cb_2017_us_county_20m.json
# outfile = static\assets\geojson\FinalGeoFile2017.json
# infile = RawData\cb_2018_us_county_20m.json
# outfile = static\assets\geojson\FinalGeoFile2018.json
# infile = RawData\tl_2019_us_county.json
# outfile = static\assets\geojson\FinalGeoFile2019.json

# %%
# print out statements that we can paste into javascript

# %%
def printlinks(year):
    print(f'countyLink{year} = "/static/assets/geojson/FinalGeoFile{year}.json";')
    
printlinks(1970)
printlinks(1980)
for year in range(1990,2020):
    printlinks(year)
# Out:
# countyLink1970 = "/static/assets/geojson/FinalGeoFile1970.json";
# countyLink1980 = "/static/assets/geojson/FinalGeoFile1980.json";
# countyLink1990 = "/static/assets/geojson/FinalGeoFile1990.json";
# countyLink1991 = "/static/assets/geojson/FinalGeoFile1991.json";
# countyLink1992 = "/static/assets/geojson/FinalGeoFile1992.json";
# countyLink1993 = "/static/assets/geojson/FinalGeoFile1993.json";
# countyLink1994 = "/static/assets/geojson/FinalGeoFile1994.json";
# countyLink1995 = "/static/assets/geojson/FinalGeoFile1995.json";
# countyLink1996 = "/static/assets/geojson/FinalGeoFile1996.json";
# countyLink1997 = "/static/assets/geojson/FinalGeoFile1997.json";
# countyLink1998 = "/static/assets/geojson/FinalGeoFile1998.json";
# countyLink1999 = "/static/assets/geojson/FinalGeoFile1999.json";
# countyLink2000 = "/static/assets/geojson/FinalGeoFile2000.json";
# countyLink2001 = "/static/assets/geojson/FinalGeoFile2001.json";
# countyLink2002 = "/static/assets/geojson/FinalGeoFile2002.json";
# countyLink2003 = "/static/assets/geojson/FinalGeoFile2003.json";
# countyLink2004 = "/static/assets/geojson/FinalGeoFile2004.json";
# countyLink2005 = "/static/assets/geojson/FinalGeoFile2005.json";
# countyLink2006 = "/static/assets/geojson/FinalGeoFile2006.json";
# countyLink2007 = "/static/assets/geojson/FinalGeoFile2007.json";
# countyLink2008 = "/static/assets/geojson/FinalGeoFile2008.json";
# countyLink2009 = "/static/assets/geojson/FinalGeoFile2009.json";
# countyLink2010 = "/static/assets/geojson/FinalGeoFile2010.json";
# countyLink2011 = "/static/assets/geojson/FinalGeoFile2011.json";
# countyLink2012 = "/static/assets/geojson/FinalGeoFile2012.json";
# countyLink2013 = "/static/assets/geojson/FinalGeoFile2013.json";
# countyLink2014 = "/static/assets/geojson/FinalGeoFile2014.json";
# countyLink2015 = "/static/assets/geojson/FinalGeoFile2015.json";
# countyLink2016 = "/static/assets/geojson/FinalGeoFile2016.json";
# countyLink2017 = "/static/assets/geojson/FinalGeoFile2017.json";
# countyLink2018 = "/static/assets/geojson/FinalGeoFile2018.json";
# countyLink2019 = "/static/assets/geojson/FinalGeoFile2019.json";

# %%
def printvars(year):
    print(f"var countyLayer{year} = new L.LayerGroup();")
    
printvars(1970)
printvars(1980)
for year in range(1990,2020):
    printvars(year)
# Out:
# var countyLayer1970 = new L.LayerGroup();
# var countyLayer1980 = new L.LayerGroup();
# var countyLayer1990 = new L.LayerGroup();
# var countyLayer1991 = new L.LayerGroup();
# var countyLayer1992 = new L.LayerGroup();
# var countyLayer1993 = new L.LayerGroup();
# var countyLayer1994 = new L.LayerGroup();
# var countyLayer1995 = new L.LayerGroup();
# var countyLayer1996 = new L.LayerGroup();
# var countyLayer1997 = new L.LayerGroup();
# var countyLayer1998 = new L.LayerGroup();
# var countyLayer1999 = new L.LayerGroup();
# var countyLayer2000 = new L.LayerGroup();
# var countyLayer2001 = new L.LayerGroup();
# var countyLayer2002 = new L.LayerGroup();
# var countyLayer2003 = new L.LayerGroup();
# var countyLayer2004 = new L.LayerGroup();
# var countyLayer2005 = new L.LayerGroup();
# var countyLayer2006 = new L.LayerGroup();
# var countyLayer2007 = new L.LayerGroup();
# var countyLayer2008 = new L.LayerGroup();
# var countyLayer2009 = new L.LayerGroup();
# var countyLayer2010 = new L.LayerGroup();
# var countyLayer2011 = new L.LayerGroup();
# var countyLayer2012 = new L.LayerGroup();
# var countyLayer2013 = new L.LayerGroup();
# var countyLayer2014 = new L.LayerGroup();
# var countyLayer2015 = new L.LayerGroup();
# var countyLayer2016 = new L.LayerGroup();
# var countyLayer2017 = new L.LayerGroup();
# var countyLayer2018 = new L.LayerGroup();
# var countyLayer2019 = new L.LayerGroup();

# %%
def printmonthvars(year):
    for i in range(12):
        m = i + 1
        if m < 10:
            mm = f'0{m}'
        else:
            mm = m
        yymm = str(year) + str(mm)
        print(f"var countyLayer{yymm} = new L.LayerGroup();")
        print(f"monthLayers({year},{mm},countyLink{year},countyLayer{year}{mm});")
        print(f"layers.push(countyLayer{year}{mm});")
        print(f"descrs.push({year}{mm});")
for year in range(1990,2020):
    printmonthvars(year)
# Out:
# var countyLayer199001 = new L.LayerGroup();
# monthLayers(1990,01,countyLink1990,countyLayer199001);
# layers.push(countyLayer199001);
# descrs.push(199001);
# var countyLayer199002 = new L.LayerGroup();
# monthLayers(1990,02,countyLink1990,countyLayer199002);
# layers.push(countyLayer199002);
# descrs.push(199002);
# var countyLayer199003 = new L.LayerGroup();
# monthLayers(1990,03,countyLink1990,countyLayer199003);
# layers.push(countyLayer199003);
# descrs.push(199003);
# var countyLayer199004 = new L.LayerGroup();
# monthLayers(1990,04,countyLink1990,countyLayer199004);
# layers.push(countyLayer199004);
# descrs.push(199004);
# var countyLayer199005 = new L.LayerGroup();
# monthLayers(1990,05,countyLink1990,countyLayer199005);
# layers.push(countyLayer199005);
# descrs.push(199005);
# var countyLayer199006 = new L.LayerGroup();
# monthLayers(1990,06,countyLink1990,countyLayer199006);
# layers.push(countyLayer199006);
# descrs.push(199006);
# var countyLayer199007 = new L.LayerGroup();
# monthLayers(1990,07,countyLink1990,countyLayer199007);
# layers.push(countyLayer199007);
# descrs.push(199007);
# var countyLayer199008 = new L.LayerGroup();
# monthLayers(1990,08,countyLink1990,countyLayer199008);
# layers.push(countyLayer199008);
# descrs.push(199008);
# var countyLayer199009 = new L.LayerGroup();
# monthLayers(1990,09,countyLink1990,countyLayer199009);
# layers.push(countyLayer199009);
# descrs.push(199009);
# var countyLayer199010 = new L.LayerGroup();
# monthLayers(1990,10,countyLink1990,countyLayer199010);
# layers.push(countyLayer199010);
# descrs.push(199010);
# var countyLayer199011 = new L.LayerGroup();
# monthLayers(1990,11,countyLink1990,countyLayer199011);
# layers.push(countyLayer199011);
# descrs.push(199011);
# var countyLayer199012 = new L.LayerGroup();
# monthLayers(1990,12,countyLink1990,countyLayer199012);
# layers.push(countyLayer199012);
# descrs.push(199012);
# var countyLayer199101 = new L.LayerGroup();
# monthLayers(1991,01,countyLink1991,countyLayer199101);
# layers.push(countyLayer199101);
# descrs.push(199101);
# var countyLayer199102 = new L.LayerGroup();
# monthLayers(1991,02,countyLink1991,countyLayer199102);
# layers.push(countyLayer199102);
# descrs.push(199102);
# var countyLayer199103 = new L.LayerGroup();
# monthLayers(1991,03,countyLink1991,countyLayer199103);
# layers.push(countyLayer199103);
# descrs.push(199103);
# var countyLayer199104 = new L.LayerGroup();
# monthLayers(1991,04,countyLink1991,countyLayer199104);
# layers.push(countyLayer199104);
# descrs.push(199104);
# var countyLayer199105 = new L.LayerGroup();
# monthLayers(1991,05,countyLink1991,countyLayer199105);
# layers.push(countyLayer199105);
# descrs.push(199105);
# var countyLayer199106 = new L.LayerGroup();
# monthLayers(1991,06,countyLink1991,countyLayer199106);
# layers.push(countyLayer199106);
# descrs.push(199106);
# var countyLayer199107 = new L.LayerGroup();
# monthLayers(1991,07,countyLink1991,countyLayer199107);
# layers.push(countyLayer199107);
# descrs.push(199107);
# var countyLayer199108 = new L.LayerGroup();
# monthLayers(1991,08,countyLink1991,countyLayer199108);
# layers.push(countyLayer199108);
# descrs.push(199108);
# var countyLayer199109 = new L.LayerGroup();
# monthLayers(1991,09,countyLink1991,countyLayer199109);
# layers.push(countyLayer199109);
# descrs.push(199109);
# var countyLayer199110 = new L.LayerGroup();
# monthLayers(1991,10,countyLink1991,countyLayer199110);
# layers.push(countyLayer199110);
# descrs.push(199110);
# var countyLayer199111 = new L.LayerGroup();
# monthLayers(1991,11,countyLink1991,countyLayer199111);
# layers.push(countyLayer199111);
# descrs.push(199111);
# var countyLayer199112 = new L.LayerGroup();
# monthLayers(1991,12,countyLink1991,countyLayer199112);
# layers.push(countyLayer199112);
# descrs.push(199112);
# var countyLayer199201 = new L.LayerGroup();
# monthLayers(1992,01,countyLink1992,countyLayer199201);
# layers.push(countyLayer199201);
# descrs.push(199201);
# var countyLayer199202 = new L.LayerGroup();
# monthLayers(1992,02,countyLink1992,countyLayer199202);
# layers.push(countyLayer199202);
# descrs.push(199202);
# var countyLayer199203 = new L.LayerGroup();
# monthLayers(1992,03,countyLink1992,countyLayer199203);
# layers.push(countyLayer199203);
# descrs.push(199203);
# var countyLayer199204 = new L.LayerGroup();
# monthLayers(1992,04,countyLink1992,countyLayer199204);
# layers.push(countyLayer199204);
# descrs.push(199204);
# var countyLayer199205 = new L.LayerGroup();
# monthLayers(1992,05,countyLink1992,countyLayer199205);
# layers.push(countyLayer199205);
# descrs.push(199205);
# var countyLayer199206 = new L.LayerGroup();
# monthLayers(1992,06,countyLink1992,countyLayer199206);
# layers.push(countyLayer199206);
# descrs.push(199206);
# var countyLayer199207 = new L.LayerGroup();
# monthLayers(1992,07,countyLink1992,countyLayer199207);
# layers.push(countyLayer199207);
# descrs.push(199207);
# var countyLayer199208 = new L.LayerGroup();
# monthLayers(1992,08,countyLink1992,countyLayer199208);
# layers.push(countyLayer199208);
# descrs.push(199208);
# var countyLayer199209 = new L.LayerGroup();
# monthLayers(1992,09,countyLink1992,countyLayer199209);
# layers.push(countyLayer199209);
# descrs.push(199209);
# var countyLayer199210 = new L.LayerGroup();
# monthLayers(1992,10,countyLink1992,countyLayer199210);
# layers.push(countyLayer199210);
# descrs.push(199210);
# var countyLayer199211 = new L.LayerGroup();
# monthLayers(1992,11,countyLink1992,countyLayer199211);
# layers.push(countyLayer199211);
# descrs.push(199211);
# var countyLayer199212 = new L.LayerGroup();
# monthLayers(1992,12,countyLink1992,countyLayer199212);
# layers.push(countyLayer199212);
# descrs.push(199212);
# var countyLayer199301 = new L.LayerGroup();
# monthLayers(1993,01,countyLink1993,countyLayer199301);
# layers.push(countyLayer199301);
# descrs.push(199301);
# var countyLayer199302 = new L.LayerGroup();
# monthLayers(1993,02,countyLink1993,countyLayer199302);
# layers.push(countyLayer199302);
# descrs.push(199302);
# var countyLayer199303 = new L.LayerGroup();
# monthLayers(1993,03,countyLink1993,countyLayer199303);
# layers.push(countyLayer199303);
# descrs.push(199303);
# var countyLayer199304 = new L.LayerGroup();
# monthLayers(1993,04,countyLink1993,countyLayer199304);
# layers.push(countyLayer199304);
# descrs.push(199304);
# var countyLayer199305 = new L.LayerGroup();
# monthLayers(1993,05,countyLink1993,countyLayer199305);
# layers.push(countyLayer199305);
# descrs.push(199305);
# var countyLayer199306 = new L.LayerGroup();
# monthLayers(1993,06,countyLink1993,countyLayer199306);
# layers.push(countyLayer199306);
# descrs.push(199306);
# var countyLayer199307 = new L.LayerGroup();
# monthLayers(1993,07,countyLink1993,countyLayer199307);
# layers.push(countyLayer199307);
# descrs.push(199307);
# var countyLayer199308 = new L.LayerGroup();
# monthLayers(1993,08,countyLink1993,countyLayer199308);
# layers.push(countyLayer199308);
# descrs.push(199308);
# var countyLayer199309 = new L.LayerGroup();
# monthLayers(1993,09,countyLink1993,countyLayer199309);
# layers.push(countyLayer199309);
# descrs.push(199309);
# var countyLayer199310 = new L.LayerGroup();
# monthLayers(1993,10,countyLink1993,countyLayer199310);
# layers.push(countyLayer199310);
# descrs.push(199310);
# var countyLayer199311 = new L.LayerGroup();
# monthLayers(1993,11,countyLink1993,countyLayer199311);
# layers.push(countyLayer199311);
# descrs.push(199311);
# var countyLayer199312 = new L.LayerGroup();
# monthLayers(1993,12,countyLink1993,countyLayer199312);
# layers.push(countyLayer199312);
# descrs.push(199312);
# var countyLayer199401 = new L.LayerGroup();
# monthLayers(1994,01,countyLink1994,countyLayer199401);
# layers.push(countyLayer199401);
# descrs.push(199401);
# var countyLayer199402 = new L.LayerGroup();
# monthLayers(1994,02,countyLink1994,countyLayer199402);
# layers.push(countyLayer199402);
# descrs.push(199402);
# var countyLayer199403 = new L.LayerGroup();
# monthLayers(1994,03,countyLink1994,countyLayer199403);
# layers.push(countyLayer199403);
# descrs.push(199403);
# var countyLayer199404 = new L.LayerGroup();
# monthLayers(1994,04,countyLink1994,countyLayer199404);
# layers.push(countyLayer199404);
# descrs.push(199404);
# var countyLayer199405 = new L.LayerGroup();
# monthLayers(1994,05,countyLink1994,countyLayer199405);
# layers.push(countyLayer199405);
# descrs.push(199405);
# var countyLayer199406 = new L.LayerGroup();
# monthLayers(1994,06,countyLink1994,countyLayer199406);
# layers.push(countyLayer199406);
# descrs.push(199406);
# var countyLayer199407 = new L.LayerGroup();
# monthLayers(1994,07,countyLink1994,countyLayer199407);
# layers.push(countyLayer199407);
# descrs.push(199407);
# var countyLayer199408 = new L.LayerGroup();
# monthLayers(1994,08,countyLink1994,countyLayer199408);
# layers.push(countyLayer199408);
# descrs.push(199408);
# var countyLayer199409 = new L.LayerGroup();
# monthLayers(1994,09,countyLink1994,countyLayer199409);
# layers.push(countyLayer199409);
# descrs.push(199409);
# var countyLayer199410 = new L.LayerGroup();
# monthLayers(1994,10,countyLink1994,countyLayer199410);
# layers.push(countyLayer199410);
# descrs.push(199410);
# var countyLayer199411 = new L.LayerGroup();
# monthLayers(1994,11,countyLink1994,countyLayer199411);
# layers.push(countyLayer199411);
# descrs.push(199411);
# var countyLayer199412 = new L.LayerGroup();
# monthLayers(1994,12,countyLink1994,countyLayer199412);
# layers.push(countyLayer199412);
# descrs.push(199412);
# var countyLayer199501 = new L.LayerGroup();
# monthLayers(1995,01,countyLink1995,countyLayer199501);
# layers.push(countyLayer199501);
# descrs.push(199501);
# var countyLayer199502 = new L.LayerGroup();
# monthLayers(1995,02,countyLink1995,countyLayer199502);
# layers.push(countyLayer199502);
# descrs.push(199502);
# var countyLayer199503 = new L.LayerGroup();
# monthLayers(1995,03,countyLink1995,countyLayer199503);
# layers.push(countyLayer199503);
# descrs.push(199503);
# var countyLayer199504 = new L.LayerGroup();
# monthLayers(1995,04,countyLink1995,countyLayer199504);
# layers.push(countyLayer199504);
# descrs.push(199504);
# var countyLayer199505 = new L.LayerGroup();
# monthLayers(1995,05,countyLink1995,countyLayer199505);
# layers.push(countyLayer199505);
# descrs.push(199505);
# var countyLayer199506 = new L.LayerGroup();
# monthLayers(1995,06,countyLink1995,countyLayer199506);
# layers.push(countyLayer199506);
# descrs.push(199506);
# var countyLayer199507 = new L.LayerGroup();
# monthLayers(1995,07,countyLink1995,countyLayer199507);
# layers.push(countyLayer199507);
# descrs.push(199507);
# var countyLayer199508 = new L.LayerGroup();
# monthLayers(1995,08,countyLink1995,countyLayer199508);
# layers.push(countyLayer199508);
# descrs.push(199508);
# var countyLayer199509 = new L.LayerGroup();
# monthLayers(1995,09,countyLink1995,countyLayer199509);
# layers.push(countyLayer199509);
# descrs.push(199509);
# var countyLayer199510 = new L.LayerGroup();
# monthLayers(1995,10,countyLink1995,countyLayer199510);
# layers.push(countyLayer199510);
# descrs.push(199510);
# var countyLayer199511 = new L.LayerGroup();
# monthLayers(1995,11,countyLink1995,countyLayer199511);
# layers.push(countyLayer199511);
# descrs.push(199511);
# var countyLayer199512 = new L.LayerGroup();
# monthLayers(1995,12,countyLink1995,countyLayer199512);
# layers.push(countyLayer199512);
# descrs.push(199512);
# var countyLayer199601 = new L.LayerGroup();
# monthLayers(1996,01,countyLink1996,countyLayer199601);
# layers.push(countyLayer199601);
# descrs.push(199601);
# var countyLayer199602 = new L.LayerGroup();
# monthLayers(1996,02,countyLink1996,countyLayer199602);
# layers.push(countyLayer199602);
# descrs.push(199602);
# var countyLayer199603 = new L.LayerGroup();
# monthLayers(1996,03,countyLink1996,countyLayer199603);
# layers.push(countyLayer199603);
# descrs.push(199603);
# var countyLayer199604 = new L.LayerGroup();
# monthLayers(1996,04,countyLink1996,countyLayer199604);
# layers.push(countyLayer199604);
# descrs.push(199604);
# var countyLayer199605 = new L.LayerGroup();
# monthLayers(1996,05,countyLink1996,countyLayer199605);
# layers.push(countyLayer199605);
# descrs.push(199605);
# var countyLayer199606 = new L.LayerGroup();
# monthLayers(1996,06,countyLink1996,countyLayer199606);
# layers.push(countyLayer199606);
# descrs.push(199606);
# var countyLayer199607 = new L.LayerGroup();
# monthLayers(1996,07,countyLink1996,countyLayer199607);
# layers.push(countyLayer199607);
# descrs.push(199607);
# var countyLayer199608 = new L.LayerGroup();
# monthLayers(1996,08,countyLink1996,countyLayer199608);
# layers.push(countyLayer199608);
# descrs.push(199608);
# var countyLayer199609 = new L.LayerGroup();
# monthLayers(1996,09,countyLink1996,countyLayer199609);
# layers.push(countyLayer199609);
# descrs.push(199609);
# var countyLayer199610 = new L.LayerGroup();
# monthLayers(1996,10,countyLink1996,countyLayer199610);
# layers.push(countyLayer199610);
# descrs.push(199610);
# var countyLayer199611 = new L.LayerGroup();
# monthLayers(1996,11,countyLink1996,countyLayer199611);
# layers.push(countyLayer199611);
# descrs.push(199611);
# var countyLayer199612 = new L.LayerGroup();
# monthLayers(1996,12,countyLink1996,countyLayer199612);
# layers.push(countyLayer199612);
# descrs.push(199612);
# var countyLayer199701 = new L.LayerGroup();
# monthLayers(1997,01,countyLink1997,countyLayer199701);
# layers.push(countyLayer199701);
# descrs.push(199701);
# var countyLayer199702 = new L.LayerGroup();
# monthLayers(1997,02,countyLink1997,countyLayer199702);
# layers.push(countyLayer199702);
# descrs.push(199702);
# var countyLayer199703 = new L.LayerGroup();
# monthLayers(1997,03,countyLink1997,countyLayer199703);
# layers.push(countyLayer199703);
# descrs.push(199703);
# var countyLayer199704 = new L.LayerGroup();
# monthLayers(1997,04,countyLink1997,countyLayer199704);
# layers.push(countyLayer199704);
# descrs.push(199704);
# var countyLayer199705 = new L.LayerGroup();
# monthLayers(1997,05,countyLink1997,countyLayer199705);
# layers.push(countyLayer199705);
# descrs.push(199705);
# var countyLayer199706 = new L.LayerGroup();
# monthLayers(1997,06,countyLink1997,countyLayer199706);
# layers.push(countyLayer199706);
# descrs.push(199706);
# var countyLayer199707 = new L.LayerGroup();
# monthLayers(1997,07,countyLink1997,countyLayer199707);
# layers.push(countyLayer199707);
# descrs.push(199707);
# var countyLayer199708 = new L.LayerGroup();
# monthLayers(1997,08,countyLink1997,countyLayer199708);
# layers.push(countyLayer199708);
# descrs.push(199708);
# var countyLayer199709 = new L.LayerGroup();
# monthLayers(1997,09,countyLink1997,countyLayer199709);
# layers.push(countyLayer199709);
# descrs.push(199709);
# var countyLayer199710 = new L.LayerGroup();
# monthLayers(1997,10,countyLink1997,countyLayer199710);
# layers.push(countyLayer199710);
# descrs.push(199710);
# var countyLayer199711 = new L.LayerGroup();
# monthLayers(1997,11,countyLink1997,countyLayer199711);
# layers.push(countyLayer199711);
# descrs.push(199711);
# var countyLayer199712 = new L.LayerGroup();
# monthLayers(1997,12,countyLink1997,countyLayer199712);
# layers.push(countyLayer199712);
# descrs.push(199712);
# var countyLayer199801 = new L.LayerGroup();
# monthLayers(1998,01,countyLink1998,countyLayer199801);
# layers.push(countyLayer199801);
# descrs.push(199801);
# var countyLayer199802 = new L.LayerGroup();
# monthLayers(1998,02,countyLink1998,countyLayer199802);
# layers.push(countyLayer199802);
# descrs.push(199802);
# var countyLayer199803 = new L.LayerGroup();
# monthLayers(1998,03,countyLink1998,countyLayer199803);
# layers.push(countyLayer199803);
# descrs.push(199803);
# var countyLayer199804 = new L.LayerGroup();
# monthLayers(1998,04,countyLink1998,countyLayer199804);
# layers.push(countyLayer199804);
# descrs.push(199804);
# var countyLayer199805 = new L.LayerGroup();
# monthLayers(1998,05,countyLink1998,countyLayer199805);
# layers.push(countyLayer199805);
# descrs.push(199805);
# var countyLayer199806 = new L.LayerGroup();
# monthLayers(1998,06,countyLink1998,countyLayer199806);
# layers.push(countyLayer199806);
# descrs.push(199806);
# var countyLayer199807 = new L.LayerGroup();
# monthLayers(1998,07,countyLink1998,countyLayer199807);
# layers.push(countyLayer199807);
# descrs.push(199807);
# var countyLayer199808 = new L.LayerGroup();
# monthLayers(1998,08,countyLink1998,countyLayer199808);
# layers.push(countyLayer199808);
# descrs.push(199808);
# var countyLayer199809 = new L.LayerGroup();
# monthLayers(1998,09,countyLink1998,countyLayer199809);
# layers.push(countyLayer199809);
# descrs.push(199809);
# var countyLayer199810 = new L.LayerGroup();
# monthLayers(1998,10,countyLink1998,countyLayer199810);
# layers.push(countyLayer199810);
# descrs.push(199810);
# var countyLayer199811 = new L.LayerGroup();
# monthLayers(1998,11,countyLink1998,countyLayer199811);
# layers.push(countyLayer199811);
# descrs.push(199811);
# var countyLayer199812 = new L.LayerGroup();
# monthLayers(1998,12,countyLink1998,countyLayer199812);
# layers.push(countyLayer199812);
# descrs.push(199812);
# var countyLayer199901 = new L.LayerGroup();
# monthLayers(1999,01,countyLink1999,countyLayer199901);
# layers.push(countyLayer199901);
# descrs.push(199901);
# var countyLayer199902 = new L.LayerGroup();
# monthLayers(1999,02,countyLink1999,countyLayer199902);
# layers.push(countyLayer199902);
# descrs.push(199902);
# var countyLayer199903 = new L.LayerGroup();
# monthLayers(1999,03,countyLink1999,countyLayer199903);
# layers.push(countyLayer199903);
# descrs.push(199903);
# var countyLayer199904 = new L.LayerGroup();
# monthLayers(1999,04,countyLink1999,countyLayer199904);
# layers.push(countyLayer199904);
# descrs.push(199904);
# var countyLayer199905 = new L.LayerGroup();
# monthLayers(1999,05,countyLink1999,countyLayer199905);
# layers.push(countyLayer199905);
# descrs.push(199905);
# var countyLayer199906 = new L.LayerGroup();
# monthLayers(1999,06,countyLink1999,countyLayer199906);
# layers.push(countyLayer199906);
# descrs.push(199906);
# var countyLayer199907 = new L.LayerGroup();
# monthLayers(1999,07,countyLink1999,countyLayer199907);
# layers.push(countyLayer199907);
# descrs.push(199907);
# var countyLayer199908 = new L.LayerGroup();
# monthLayers(1999,08,countyLink1999,countyLayer199908);
# layers.push(countyLayer199908);
# descrs.push(199908);
# var countyLayer199909 = new L.LayerGroup();
# monthLayers(1999,09,countyLink1999,countyLayer199909);
# layers.push(countyLayer199909);
# descrs.push(199909);
# var countyLayer199910 = new L.LayerGroup();
# monthLayers(1999,10,countyLink1999,countyLayer199910);
# layers.push(countyLayer199910);
# descrs.push(199910);
# var countyLayer199911 = new L.LayerGroup();
# monthLayers(1999,11,countyLink1999,countyLayer199911);
# layers.push(countyLayer199911);
# descrs.push(199911);
# var countyLayer199912 = new L.LayerGroup();
# monthLayers(1999,12,countyLink1999,countyLayer199912);
# layers.push(countyLayer199912);
# descrs.push(199912);
# var countyLayer200001 = new L.LayerGroup();
# monthLayers(2000,01,countyLink2000,countyLayer200001);
# layers.push(countyLayer200001);
# descrs.push(200001);
# var countyLayer200002 = new L.LayerGroup();
# monthLayers(2000,02,countyLink2000,countyLayer200002);
# layers.push(countyLayer200002);
# descrs.push(200002);
# var countyLayer200003 = new L.LayerGroup();
# monthLayers(2000,03,countyLink2000,countyLayer200003);
# layers.push(countyLayer200003);
# descrs.push(200003);
# var countyLayer200004 = new L.LayerGroup();
# monthLayers(2000,04,countyLink2000,countyLayer200004);
# layers.push(countyLayer200004);
# descrs.push(200004);
# var countyLayer200005 = new L.LayerGroup();
# monthLayers(2000,05,countyLink2000,countyLayer200005);
# layers.push(countyLayer200005);
# descrs.push(200005);
# var countyLayer200006 = new L.LayerGroup();
# monthLayers(2000,06,countyLink2000,countyLayer200006);
# layers.push(countyLayer200006);
# descrs.push(200006);
# var countyLayer200007 = new L.LayerGroup();
# monthLayers(2000,07,countyLink2000,countyLayer200007);
# layers.push(countyLayer200007);
# descrs.push(200007);
# var countyLayer200008 = new L.LayerGroup();
# monthLayers(2000,08,countyLink2000,countyLayer200008);
# layers.push(countyLayer200008);
# descrs.push(200008);
# var countyLayer200009 = new L.LayerGroup();
# monthLayers(2000,09,countyLink2000,countyLayer200009);
# layers.push(countyLayer200009);
# descrs.push(200009);
# var countyLayer200010 = new L.LayerGroup();
# monthLayers(2000,10,countyLink2000,countyLayer200010);
# layers.push(countyLayer200010);
# descrs.push(200010);
# var countyLayer200011 = new L.LayerGroup();
# monthLayers(2000,11,countyLink2000,countyLayer200011);
# layers.push(countyLayer200011);
# descrs.push(200011);
# var countyLayer200012 = new L.LayerGroup();
# monthLayers(2000,12,countyLink2000,countyLayer200012);
# layers.push(countyLayer200012);
# descrs.push(200012);
# var countyLayer200101 = new L.LayerGroup();
# monthLayers(2001,01,countyLink2001,countyLayer200101);
# layers.push(countyLayer200101);
# descrs.push(200101);
# var countyLayer200102 = new L.LayerGroup();
# monthLayers(2001,02,countyLink2001,countyLayer200102);
# layers.push(countyLayer200102);
# descrs.push(200102);
# var countyLayer200103 = new L.LayerGroup();
# monthLayers(2001,03,countyLink2001,countyLayer200103);
# layers.push(countyLayer200103);
# descrs.push(200103);
# var countyLayer200104 = new L.LayerGroup();
# monthLayers(2001,04,countyLink2001,countyLayer200104);
# layers.push(countyLayer200104);
# descrs.push(200104);
# var countyLayer200105 = new L.LayerGroup();
# monthLayers(2001,05,countyLink2001,countyLayer200105);
# layers.push(countyLayer200105);
# descrs.push(200105);
# var countyLayer200106 = new L.LayerGroup();
# monthLayers(2001,06,countyLink2001,countyLayer200106);
# layers.push(countyLayer200106);
# descrs.push(200106);
# var countyLayer200107 = new L.LayerGroup();
# monthLayers(2001,07,countyLink2001,countyLayer200107);
# layers.push(countyLayer200107);
# descrs.push(200107);
# var countyLayer200108 = new L.LayerGroup();
# monthLayers(2001,08,countyLink2001,countyLayer200108);
# layers.push(countyLayer200108);
# descrs.push(200108);
# var countyLayer200109 = new L.LayerGroup();
# monthLayers(2001,09,countyLink2001,countyLayer200109);
# layers.push(countyLayer200109);
# descrs.push(200109);
# var countyLayer200110 = new L.LayerGroup();
# monthLayers(2001,10,countyLink2001,countyLayer200110);
# layers.push(countyLayer200110);
# descrs.push(200110);
# var countyLayer200111 = new L.LayerGroup();
# monthLayers(2001,11,countyLink2001,countyLayer200111);
# layers.push(countyLayer200111);
# descrs.push(200111);
# var countyLayer200112 = new L.LayerGroup();
# monthLayers(2001,12,countyLink2001,countyLayer200112);
# layers.push(countyLayer200112);
# descrs.push(200112);
# var countyLayer200201 = new L.LayerGroup();
# monthLayers(2002,01,countyLink2002,countyLayer200201);
# layers.push(countyLayer200201);
# descrs.push(200201);
# var countyLayer200202 = new L.LayerGroup();
# monthLayers(2002,02,countyLink2002,countyLayer200202);
# layers.push(countyLayer200202);
# descrs.push(200202);
# var countyLayer200203 = new L.LayerGroup();
# monthLayers(2002,03,countyLink2002,countyLayer200203);
# layers.push(countyLayer200203);
# descrs.push(200203);
# var countyLayer200204 = new L.LayerGroup();
# monthLayers(2002,04,countyLink2002,countyLayer200204);
# layers.push(countyLayer200204);
# descrs.push(200204);
# var countyLayer200205 = new L.LayerGroup();
# monthLayers(2002,05,countyLink2002,countyLayer200205);
# layers.push(countyLayer200205);
# descrs.push(200205);
# var countyLayer200206 = new L.LayerGroup();
# monthLayers(2002,06,countyLink2002,countyLayer200206);
# layers.push(countyLayer200206);
# descrs.push(200206);
# var countyLayer200207 = new L.LayerGroup();
# monthLayers(2002,07,countyLink2002,countyLayer200207);
# layers.push(countyLayer200207);
# descrs.push(200207);
# var countyLayer200208 = new L.LayerGroup();
# monthLayers(2002,08,countyLink2002,countyLayer200208);
# layers.push(countyLayer200208);
# descrs.push(200208);
# var countyLayer200209 = new L.LayerGroup();
# monthLayers(2002,09,countyLink2002,countyLayer200209);
# layers.push(countyLayer200209);
# descrs.push(200209);
# var countyLayer200210 = new L.LayerGroup();
# monthLayers(2002,10,countyLink2002,countyLayer200210);
# layers.push(countyLayer200210);
# descrs.push(200210);
# var countyLayer200211 = new L.LayerGroup();
# monthLayers(2002,11,countyLink2002,countyLayer200211);
# layers.push(countyLayer200211);
# descrs.push(200211);
# var countyLayer200212 = new L.LayerGroup();
# monthLayers(2002,12,countyLink2002,countyLayer200212);
# layers.push(countyLayer200212);
# descrs.push(200212);
# var countyLayer200301 = new L.LayerGroup();
# monthLayers(2003,01,countyLink2003,countyLayer200301);
# layers.push(countyLayer200301);
# descrs.push(200301);
# var countyLayer200302 = new L.LayerGroup();
# monthLayers(2003,02,countyLink2003,countyLayer200302);
# layers.push(countyLayer200302);
# descrs.push(200302);
# var countyLayer200303 = new L.LayerGroup();
# monthLayers(2003,03,countyLink2003,countyLayer200303);
# layers.push(countyLayer200303);
# descrs.push(200303);
# var countyLayer200304 = new L.LayerGroup();
# monthLayers(2003,04,countyLink2003,countyLayer200304);
# layers.push(countyLayer200304);
# descrs.push(200304);
# var countyLayer200305 = new L.LayerGroup();
# monthLayers(2003,05,countyLink2003,countyLayer200305);
# layers.push(countyLayer200305);
# descrs.push(200305);
# var countyLayer200306 = new L.LayerGroup();
# monthLayers(2003,06,countyLink2003,countyLayer200306);
# layers.push(countyLayer200306);
# descrs.push(200306);
# var countyLayer200307 = new L.LayerGroup();
# monthLayers(2003,07,countyLink2003,countyLayer200307);
# layers.push(countyLayer200307);
# descrs.push(200307);
# var countyLayer200308 = new L.LayerGroup();
# monthLayers(2003,08,countyLink2003,countyLayer200308);
# layers.push(countyLayer200308);
# descrs.push(200308);
# var countyLayer200309 = new L.LayerGroup();
# monthLayers(2003,09,countyLink2003,countyLayer200309);
# layers.push(countyLayer200309);
# descrs.push(200309);
# var countyLayer200310 = new L.LayerGroup();
# monthLayers(2003,10,countyLink2003,countyLayer200310);
# layers.push(countyLayer200310);
# descrs.push(200310);
# var countyLayer200311 = new L.LayerGroup();
# monthLayers(2003,11,countyLink2003,countyLayer200311);
# layers.push(countyLayer200311);
# descrs.push(200311);
# var countyLayer200312 = new L.LayerGroup();
# monthLayers(2003,12,countyLink2003,countyLayer200312);
# layers.push(countyLayer200312);
# descrs.push(200312);
# var countyLayer200401 = new L.LayerGroup();
# monthLayers(2004,01,countyLink2004,countyLayer200401);
# layers.push(countyLayer200401);
# descrs.push(200401);
# var countyLayer200402 = new L.LayerGroup();
# monthLayers(2004,02,countyLink2004,countyLayer200402);
# layers.push(countyLayer200402);
# descrs.push(200402);
# var countyLayer200403 = new L.LayerGroup();
# monthLayers(2004,03,countyLink2004,countyLayer200403);
# layers.push(countyLayer200403);
# descrs.push(200403);
# var countyLayer200404 = new L.LayerGroup();
# monthLayers(2004,04,countyLink2004,countyLayer200404);
# layers.push(countyLayer200404);
# descrs.push(200404);
# var countyLayer200405 = new L.LayerGroup();
# monthLayers(2004,05,countyLink2004,countyLayer200405);
# layers.push(countyLayer200405);
# descrs.push(200405);
# var countyLayer200406 = new L.LayerGroup();
# monthLayers(2004,06,countyLink2004,countyLayer200406);
# layers.push(countyLayer200406);
# descrs.push(200406);
# var countyLayer200407 = new L.LayerGroup();
# monthLayers(2004,07,countyLink2004,countyLayer200407);
# layers.push(countyLayer200407);
# descrs.push(200407);
# var countyLayer200408 = new L.LayerGroup();
# monthLayers(2004,08,countyLink2004,countyLayer200408);
# layers.push(countyLayer200408);
# descrs.push(200408);
# var countyLayer200409 = new L.LayerGroup();
# monthLayers(2004,09,countyLink2004,countyLayer200409);
# layers.push(countyLayer200409);
# descrs.push(200409);
# var countyLayer200410 = new L.LayerGroup();
# monthLayers(2004,10,countyLink2004,countyLayer200410);
# layers.push(countyLayer200410);
# descrs.push(200410);
# var countyLayer200411 = new L.LayerGroup();
# monthLayers(2004,11,countyLink2004,countyLayer200411);
# layers.push(countyLayer200411);
# descrs.push(200411);
# var countyLayer200412 = new L.LayerGroup();
# monthLayers(2004,12,countyLink2004,countyLayer200412);
# layers.push(countyLayer200412);
# descrs.push(200412);
# var countyLayer200501 = new L.LayerGroup();
# monthLayers(2005,01,countyLink2005,countyLayer200501);
# layers.push(countyLayer200501);
# descrs.push(200501);
# var countyLayer200502 = new L.LayerGroup();
# monthLayers(2005,02,countyLink2005,countyLayer200502);
# layers.push(countyLayer200502);
# descrs.push(200502);
# var countyLayer200503 = new L.LayerGroup();
# monthLayers(2005,03,countyLink2005,countyLayer200503);
# layers.push(countyLayer200503);
# descrs.push(200503);
# var countyLayer200504 = new L.LayerGroup();
# monthLayers(2005,04,countyLink2005,countyLayer200504);
# layers.push(countyLayer200504);
# descrs.push(200504);
# var countyLayer200505 = new L.LayerGroup();
# monthLayers(2005,05,countyLink2005,countyLayer200505);
# layers.push(countyLayer200505);
# descrs.push(200505);
# var countyLayer200506 = new L.LayerGroup();
# monthLayers(2005,06,countyLink2005,countyLayer200506);
# layers.push(countyLayer200506);
# descrs.push(200506);
# var countyLayer200507 = new L.LayerGroup();
# monthLayers(2005,07,countyLink2005,countyLayer200507);
# layers.push(countyLayer200507);
# descrs.push(200507);
# var countyLayer200508 = new L.LayerGroup();
# monthLayers(2005,08,countyLink2005,countyLayer200508);
# layers.push(countyLayer200508);
# descrs.push(200508);
# var countyLayer200509 = new L.LayerGroup();
# monthLayers(2005,09,countyLink2005,countyLayer200509);
# layers.push(countyLayer200509);
# descrs.push(200509);
# var countyLayer200510 = new L.LayerGroup();
# monthLayers(2005,10,countyLink2005,countyLayer200510);
# layers.push(countyLayer200510);
# descrs.push(200510);
# var countyLayer200511 = new L.LayerGroup();
# monthLayers(2005,11,countyLink2005,countyLayer200511);
# layers.push(countyLayer200511);
# descrs.push(200511);
# var countyLayer200512 = new L.LayerGroup();
# monthLayers(2005,12,countyLink2005,countyLayer200512);
# layers.push(countyLayer200512);
# descrs.push(200512);
# var countyLayer200601 = new L.LayerGroup();
# monthLayers(2006,01,countyLink2006,countyLayer200601);
# layers.push(countyLayer200601);
# descrs.push(200601);
# var countyLayer200602 = new L.LayerGroup();
# monthLayers(2006,02,countyLink2006,countyLayer200602);
# layers.push(countyLayer200602);
# descrs.push(200602);
# var countyLayer200603 = new L.LayerGroup();
# monthLayers(2006,03,countyLink2006,countyLayer200603);
# layers.push(countyLayer200603);
# descrs.push(200603);
# var countyLayer200604 = new L.LayerGroup();
# monthLayers(2006,04,countyLink2006,countyLayer200604);
# layers.push(countyLayer200604);
# descrs.push(200604);
# var countyLayer200605 = new L.LayerGroup();
# monthLayers(2006,05,countyLink2006,countyLayer200605);
# layers.push(countyLayer200605);
# descrs.push(200605);
# var countyLayer200606 = new L.LayerGroup();
# monthLayers(2006,06,countyLink2006,countyLayer200606);
# layers.push(countyLayer200606);
# descrs.push(200606);
# var countyLayer200607 = new L.LayerGroup();
# monthLayers(2006,07,countyLink2006,countyLayer200607);
# layers.push(countyLayer200607);
# descrs.push(200607);
# var countyLayer200608 = new L.LayerGroup();
# monthLayers(2006,08,countyLink2006,countyLayer200608);
# layers.push(countyLayer200608);
# descrs.push(200608);
# var countyLayer200609 = new L.LayerGroup();
# monthLayers(2006,09,countyLink2006,countyLayer200609);
# layers.push(countyLayer200609);
# descrs.push(200609);
# var countyLayer200610 = new L.LayerGroup();
# monthLayers(2006,10,countyLink2006,countyLayer200610);
# layers.push(countyLayer200610);
# descrs.push(200610);
# var countyLayer200611 = new L.LayerGroup();
# monthLayers(2006,11,countyLink2006,countyLayer200611);
# layers.push(countyLayer200611);
# descrs.push(200611);
# var countyLayer200612 = new L.LayerGroup();
# monthLayers(2006,12,countyLink2006,countyLayer200612);
# layers.push(countyLayer200612);
# descrs.push(200612);
# var countyLayer200701 = new L.LayerGroup();
# monthLayers(2007,01,countyLink2007,countyLayer200701);
# layers.push(countyLayer200701);
# descrs.push(200701);
# var countyLayer200702 = new L.LayerGroup();
# monthLayers(2007,02,countyLink2007,countyLayer200702);
# layers.push(countyLayer200702);
# descrs.push(200702);
# var countyLayer200703 = new L.LayerGroup();
# monthLayers(2007,03,countyLink2007,countyLayer200703);
# layers.push(countyLayer200703);
# descrs.push(200703);
# var countyLayer200704 = new L.LayerGroup();
# monthLayers(2007,04,countyLink2007,countyLayer200704);
# layers.push(countyLayer200704);
# descrs.push(200704);
# var countyLayer200705 = new L.LayerGroup();
# monthLayers(2007,05,countyLink2007,countyLayer200705);
# layers.push(countyLayer200705);
# descrs.push(200705);
# var countyLayer200706 = new L.LayerGroup();
# monthLayers(2007,06,countyLink2007,countyLayer200706);
# layers.push(countyLayer200706);
# descrs.push(200706);
# var countyLayer200707 = new L.LayerGroup();
# monthLayers(2007,07,countyLink2007,countyLayer200707);
# layers.push(countyLayer200707);
# descrs.push(200707);
# var countyLayer200708 = new L.LayerGroup();
# monthLayers(2007,08,countyLink2007,countyLayer200708);
# layers.push(countyLayer200708);
# descrs.push(200708);
# var countyLayer200709 = new L.LayerGroup();
# monthLayers(2007,09,countyLink2007,countyLayer200709);
# layers.push(countyLayer200709);
# descrs.push(200709);
# var countyLayer200710 = new L.LayerGroup();
# monthLayers(2007,10,countyLink2007,countyLayer200710);
# layers.push(countyLayer200710);
# descrs.push(200710);
# var countyLayer200711 = new L.LayerGroup();
# monthLayers(2007,11,countyLink2007,countyLayer200711);
# layers.push(countyLayer200711);
# descrs.push(200711);
# var countyLayer200712 = new L.LayerGroup();
# monthLayers(2007,12,countyLink2007,countyLayer200712);
# layers.push(countyLayer200712);
# descrs.push(200712);
# var countyLayer200801 = new L.LayerGroup();
# monthLayers(2008,01,countyLink2008,countyLayer200801);
# layers.push(countyLayer200801);
# descrs.push(200801);
# var countyLayer200802 = new L.LayerGroup();
# monthLayers(2008,02,countyLink2008,countyLayer200802);
# layers.push(countyLayer200802);
# descrs.push(200802);
# var countyLayer200803 = new L.LayerGroup();
# monthLayers(2008,03,countyLink2008,countyLayer200803);
# layers.push(countyLayer200803);
# descrs.push(200803);
# var countyLayer200804 = new L.LayerGroup();
# monthLayers(2008,04,countyLink2008,countyLayer200804);
# layers.push(countyLayer200804);
# descrs.push(200804);
# var countyLayer200805 = new L.LayerGroup();
# monthLayers(2008,05,countyLink2008,countyLayer200805);
# layers.push(countyLayer200805);
# descrs.push(200805);
# var countyLayer200806 = new L.LayerGroup();
# monthLayers(2008,06,countyLink2008,countyLayer200806);
# layers.push(countyLayer200806);
# descrs.push(200806);
# var countyLayer200807 = new L.LayerGroup();
# monthLayers(2008,07,countyLink2008,countyLayer200807);
# layers.push(countyLayer200807);
# descrs.push(200807);
# var countyLayer200808 = new L.LayerGroup();
# monthLayers(2008,08,countyLink2008,countyLayer200808);
# layers.push(countyLayer200808);
# descrs.push(200808);
# var countyLayer200809 = new L.LayerGroup();
# monthLayers(2008,09,countyLink2008,countyLayer200809);
# layers.push(countyLayer200809);
# descrs.push(200809);
# var countyLayer200810 = new L.LayerGroup();
# monthLayers(2008,10,countyLink2008,countyLayer200810);
# layers.push(countyLayer200810);
# descrs.push(200810);
# var countyLayer200811 = new L.LayerGroup();
# monthLayers(2008,11,countyLink2008,countyLayer200811);
# layers.push(countyLayer200811);
# descrs.push(200811);
# var countyLayer200812 = new L.LayerGroup();
# monthLayers(2008,12,countyLink2008,countyLayer200812);
# layers.push(countyLayer200812);
# descrs.push(200812);
# var countyLayer200901 = new L.LayerGroup();
# monthLayers(2009,01,countyLink2009,countyLayer200901);
# layers.push(countyLayer200901);
# descrs.push(200901);
# var countyLayer200902 = new L.LayerGroup();
# monthLayers(2009,02,countyLink2009,countyLayer200902);
# layers.push(countyLayer200902);
# descrs.push(200902);
# var countyLayer200903 = new L.LayerGroup();
# monthLayers(2009,03,countyLink2009,countyLayer200903);
# layers.push(countyLayer200903);
# descrs.push(200903);
# var countyLayer200904 = new L.LayerGroup();
# monthLayers(2009,04,countyLink2009,countyLayer200904);
# layers.push(countyLayer200904);
# descrs.push(200904);
# var countyLayer200905 = new L.LayerGroup();
# monthLayers(2009,05,countyLink2009,countyLayer200905);
# layers.push(countyLayer200905);
# descrs.push(200905);
# var countyLayer200906 = new L.LayerGroup();
# monthLayers(2009,06,countyLink2009,countyLayer200906);
# layers.push(countyLayer200906);
# descrs.push(200906);
# var countyLayer200907 = new L.LayerGroup();
# monthLayers(2009,07,countyLink2009,countyLayer200907);
# layers.push(countyLayer200907);
# descrs.push(200907);
# var countyLayer200908 = new L.LayerGroup();
# monthLayers(2009,08,countyLink2009,countyLayer200908);
# layers.push(countyLayer200908);
# descrs.push(200908);
# var countyLayer200909 = new L.LayerGroup();
# monthLayers(2009,09,countyLink2009,countyLayer200909);
# layers.push(countyLayer200909);
# descrs.push(200909);
# var countyLayer200910 = new L.LayerGroup();
# monthLayers(2009,10,countyLink2009,countyLayer200910);
# layers.push(countyLayer200910);
# descrs.push(200910);
# var countyLayer200911 = new L.LayerGroup();
# monthLayers(2009,11,countyLink2009,countyLayer200911);
# layers.push(countyLayer200911);
# descrs.push(200911);
# var countyLayer200912 = new L.LayerGroup();
# monthLayers(2009,12,countyLink2009,countyLayer200912);
# layers.push(countyLayer200912);
# descrs.push(200912);
# var countyLayer201001 = new L.LayerGroup();
# monthLayers(2010,01,countyLink2010,countyLayer201001);
# layers.push(countyLayer201001);
# descrs.push(201001);
# var countyLayer201002 = new L.LayerGroup();
# monthLayers(2010,02,countyLink2010,countyLayer201002);
# layers.push(countyLayer201002);
# descrs.push(201002);
# var countyLayer201003 = new L.LayerGroup();
# monthLayers(2010,03,countyLink2010,countyLayer201003);
# layers.push(countyLayer201003);
# descrs.push(201003);
# var countyLayer201004 = new L.LayerGroup();
# monthLayers(2010,04,countyLink2010,countyLayer201004);
# layers.push(countyLayer201004);
# descrs.push(201004);
# var countyLayer201005 = new L.LayerGroup();
# monthLayers(2010,05,countyLink2010,countyLayer201005);
# layers.push(countyLayer201005);
# descrs.push(201005);
# var countyLayer201006 = new L.LayerGroup();
# monthLayers(2010,06,countyLink2010,countyLayer201006);
# layers.push(countyLayer201006);
# descrs.push(201006);
# var countyLayer201007 = new L.LayerGroup();
# monthLayers(2010,07,countyLink2010,countyLayer201007);
# layers.push(countyLayer201007);
# descrs.push(201007);
# var countyLayer201008 = new L.LayerGroup();
# monthLayers(2010,08,countyLink2010,countyLayer201008);
# layers.push(countyLayer201008);
# descrs.push(201008);
# var countyLayer201009 = new L.LayerGroup();
# monthLayers(2010,09,countyLink2010,countyLayer201009);
# layers.push(countyLayer201009);
# descrs.push(201009);
# var countyLayer201010 = new L.LayerGroup();
# monthLayers(2010,10,countyLink2010,countyLayer201010);
# layers.push(countyLayer201010);
# descrs.push(201010);
# var countyLayer201011 = new L.LayerGroup();
# monthLayers(2010,11,countyLink2010,countyLayer201011);
# layers.push(countyLayer201011);
# descrs.push(201011);
# var countyLayer201012 = new L.LayerGroup();
# monthLayers(2010,12,countyLink2010,countyLayer201012);
# layers.push(countyLayer201012);
# descrs.push(201012);
# var countyLayer201101 = new L.LayerGroup();
# monthLayers(2011,01,countyLink2011,countyLayer201101);
# layers.push(countyLayer201101);
# descrs.push(201101);
# var countyLayer201102 = new L.LayerGroup();
# monthLayers(2011,02,countyLink2011,countyLayer201102);
# layers.push(countyLayer201102);
# descrs.push(201102);
# var countyLayer201103 = new L.LayerGroup();
# monthLayers(2011,03,countyLink2011,countyLayer201103);
# layers.push(countyLayer201103);
# descrs.push(201103);
# var countyLayer201104 = new L.LayerGroup();
# monthLayers(2011,04,countyLink2011,countyLayer201104);
# layers.push(countyLayer201104);
# descrs.push(201104);
# var countyLayer201105 = new L.LayerGroup();
# monthLayers(2011,05,countyLink2011,countyLayer201105);
# layers.push(countyLayer201105);
# descrs.push(201105);
# var countyLayer201106 = new L.LayerGroup();
# monthLayers(2011,06,countyLink2011,countyLayer201106);
# layers.push(countyLayer201106);
# descrs.push(201106);
# var countyLayer201107 = new L.LayerGroup();
# monthLayers(2011,07,countyLink2011,countyLayer201107);
# layers.push(countyLayer201107);
# descrs.push(201107);
# var countyLayer201108 = new L.LayerGroup();
# monthLayers(2011,08,countyLink2011,countyLayer201108);
# layers.push(countyLayer201108);
# descrs.push(201108);
# var countyLayer201109 = new L.LayerGroup();
# monthLayers(2011,09,countyLink2011,countyLayer201109);
# layers.push(countyLayer201109);
# descrs.push(201109);
# var countyLayer201110 = new L.LayerGroup();
# monthLayers(2011,10,countyLink2011,countyLayer201110);
# layers.push(countyLayer201110);
# descrs.push(201110);
# var countyLayer201111 = new L.LayerGroup();
# monthLayers(2011,11,countyLink2011,countyLayer201111);
# layers.push(countyLayer201111);
# descrs.push(201111);
# var countyLayer201112 = new L.LayerGroup();
# monthLayers(2011,12,countyLink2011,countyLayer201112);
# layers.push(countyLayer201112);
# descrs.push(201112);
# var countyLayer201201 = new L.LayerGroup();
# monthLayers(2012,01,countyLink2012,countyLayer201201);
# layers.push(countyLayer201201);
# descrs.push(201201);
# var countyLayer201202 = new L.LayerGroup();
# monthLayers(2012,02,countyLink2012,countyLayer201202);
# layers.push(countyLayer201202);
# descrs.push(201202);
# var countyLayer201203 = new L.LayerGroup();
# monthLayers(2012,03,countyLink2012,countyLayer201203);
# layers.push(countyLayer201203);
# descrs.push(201203);
# var countyLayer201204 = new L.LayerGroup();
# monthLayers(2012,04,countyLink2012,countyLayer201204);
# layers.push(countyLayer201204);
# descrs.push(201204);
# var countyLayer201205 = new L.LayerGroup();
# monthLayers(2012,05,countyLink2012,countyLayer201205);
# layers.push(countyLayer201205);
# descrs.push(201205);
# var countyLayer201206 = new L.LayerGroup();
# monthLayers(2012,06,countyLink2012,countyLayer201206);
# layers.push(countyLayer201206);
# descrs.push(201206);
# var countyLayer201207 = new L.LayerGroup();
# monthLayers(2012,07,countyLink2012,countyLayer201207);
# layers.push(countyLayer201207);
# descrs.push(201207);
# var countyLayer201208 = new L.LayerGroup();
# monthLayers(2012,08,countyLink2012,countyLayer201208);
# layers.push(countyLayer201208);
# descrs.push(201208);
# var countyLayer201209 = new L.LayerGroup();
# monthLayers(2012,09,countyLink2012,countyLayer201209);
# layers.push(countyLayer201209);
# descrs.push(201209);
# var countyLayer201210 = new L.LayerGroup();
# monthLayers(2012,10,countyLink2012,countyLayer201210);
# layers.push(countyLayer201210);
# descrs.push(201210);
# var countyLayer201211 = new L.LayerGroup();
# monthLayers(2012,11,countyLink2012,countyLayer201211);
# layers.push(countyLayer201211);
# descrs.push(201211);
# var countyLayer201212 = new L.LayerGroup();
# monthLayers(2012,12,countyLink2012,countyLayer201212);
# layers.push(countyLayer201212);
# descrs.push(201212);
# var countyLayer201301 = new L.LayerGroup();
# monthLayers(2013,01,countyLink2013,countyLayer201301);
# layers.push(countyLayer201301);
# descrs.push(201301);
# var countyLayer201302 = new L.LayerGroup();
# monthLayers(2013,02,countyLink2013,countyLayer201302);
# layers.push(countyLayer201302);
# descrs.push(201302);
# var countyLayer201303 = new L.LayerGroup();
# monthLayers(2013,03,countyLink2013,countyLayer201303);
# layers.push(countyLayer201303);
# descrs.push(201303);
# var countyLayer201304 = new L.LayerGroup();
# monthLayers(2013,04,countyLink2013,countyLayer201304);
# layers.push(countyLayer201304);
# descrs.push(201304);
# var countyLayer201305 = new L.LayerGroup();
# monthLayers(2013,05,countyLink2013,countyLayer201305);
# layers.push(countyLayer201305);
# descrs.push(201305);
# var countyLayer201306 = new L.LayerGroup();
# monthLayers(2013,06,countyLink2013,countyLayer201306);
# layers.push(countyLayer201306);
# descrs.push(201306);
# var countyLayer201307 = new L.LayerGroup();
# monthLayers(2013,07,countyLink2013,countyLayer201307);
# layers.push(countyLayer201307);
# descrs.push(201307);
# var countyLayer201308 = new L.LayerGroup();
# monthLayers(2013,08,countyLink2013,countyLayer201308);
# layers.push(countyLayer201308);
# descrs.push(201308);
# var countyLayer201309 = new L.LayerGroup();
# monthLayers(2013,09,countyLink2013,countyLayer201309);
# layers.push(countyLayer201309);
# descrs.push(201309);
# var countyLayer201310 = new L.LayerGroup();
# monthLayers(2013,10,countyLink2013,countyLayer201310);
# layers.push(countyLayer201310);
# descrs.push(201310);
# var countyLayer201311 = new L.LayerGroup();
# monthLayers(2013,11,countyLink2013,countyLayer201311);
# layers.push(countyLayer201311);
# descrs.push(201311);
# var countyLayer201312 = new L.LayerGroup();
# monthLayers(2013,12,countyLink2013,countyLayer201312);
# layers.push(countyLayer201312);
# descrs.push(201312);
# var countyLayer201401 = new L.LayerGroup();
# monthLayers(2014,01,countyLink2014,countyLayer201401);
# layers.push(countyLayer201401);
# descrs.push(201401);
# var countyLayer201402 = new L.LayerGroup();
# monthLayers(2014,02,countyLink2014,countyLayer201402);
# layers.push(countyLayer201402);
# descrs.push(201402);
# var countyLayer201403 = new L.LayerGroup();
# monthLayers(2014,03,countyLink2014,countyLayer201403);
# layers.push(countyLayer201403);
# descrs.push(201403);
# var countyLayer201404 = new L.LayerGroup();
# monthLayers(2014,04,countyLink2014,countyLayer201404);
# layers.push(countyLayer201404);
# descrs.push(201404);
# var countyLayer201405 = new L.LayerGroup();
# monthLayers(2014,05,countyLink2014,countyLayer201405);
# layers.push(countyLayer201405);
# descrs.push(201405);
# var countyLayer201406 = new L.LayerGroup();
# monthLayers(2014,06,countyLink2014,countyLayer201406);
# layers.push(countyLayer201406);
# descrs.push(201406);
# var countyLayer201407 = new L.LayerGroup();
# monthLayers(2014,07,countyLink2014,countyLayer201407);
# layers.push(countyLayer201407);
# descrs.push(201407);
# var countyLayer201408 = new L.LayerGroup();
# monthLayers(2014,08,countyLink2014,countyLayer201408);
# layers.push(countyLayer201408);
# descrs.push(201408);
# var countyLayer201409 = new L.LayerGroup();
# monthLayers(2014,09,countyLink2014,countyLayer201409);
# layers.push(countyLayer201409);
# descrs.push(201409);
# var countyLayer201410 = new L.LayerGroup();
# monthLayers(2014,10,countyLink2014,countyLayer201410);
# layers.push(countyLayer201410);
# descrs.push(201410);
# var countyLayer201411 = new L.LayerGroup();
# monthLayers(2014,11,countyLink2014,countyLayer201411);
# layers.push(countyLayer201411);
# descrs.push(201411);
# var countyLayer201412 = new L.LayerGroup();
# monthLayers(2014,12,countyLink2014,countyLayer201412);
# layers.push(countyLayer201412);
# descrs.push(201412);
# var countyLayer201501 = new L.LayerGroup();
# monthLayers(2015,01,countyLink2015,countyLayer201501);
# layers.push(countyLayer201501);
# descrs.push(201501);
# var countyLayer201502 = new L.LayerGroup();
# monthLayers(2015,02,countyLink2015,countyLayer201502);
# layers.push(countyLayer201502);
# descrs.push(201502);
# var countyLayer201503 = new L.LayerGroup();
# monthLayers(2015,03,countyLink2015,countyLayer201503);
# layers.push(countyLayer201503);
# descrs.push(201503);
# var countyLayer201504 = new L.LayerGroup();
# monthLayers(2015,04,countyLink2015,countyLayer201504);
# layers.push(countyLayer201504);
# descrs.push(201504);
# var countyLayer201505 = new L.LayerGroup();
# monthLayers(2015,05,countyLink2015,countyLayer201505);
# layers.push(countyLayer201505);
# descrs.push(201505);
# var countyLayer201506 = new L.LayerGroup();
# monthLayers(2015,06,countyLink2015,countyLayer201506);
# layers.push(countyLayer201506);
# descrs.push(201506);
# var countyLayer201507 = new L.LayerGroup();
# monthLayers(2015,07,countyLink2015,countyLayer201507);
# layers.push(countyLayer201507);
# descrs.push(201507);
# var countyLayer201508 = new L.LayerGroup();
# monthLayers(2015,08,countyLink2015,countyLayer201508);
# layers.push(countyLayer201508);
# descrs.push(201508);
# var countyLayer201509 = new L.LayerGroup();
# monthLayers(2015,09,countyLink2015,countyLayer201509);
# layers.push(countyLayer201509);
# descrs.push(201509);
# var countyLayer201510 = new L.LayerGroup();
# monthLayers(2015,10,countyLink2015,countyLayer201510);
# layers.push(countyLayer201510);
# descrs.push(201510);
# var countyLayer201511 = new L.LayerGroup();
# monthLayers(2015,11,countyLink2015,countyLayer201511);
# layers.push(countyLayer201511);
# descrs.push(201511);
# var countyLayer201512 = new L.LayerGroup();
# monthLayers(2015,12,countyLink2015,countyLayer201512);
# layers.push(countyLayer201512);
# descrs.push(201512);
# var countyLayer201601 = new L.LayerGroup();
# monthLayers(2016,01,countyLink2016,countyLayer201601);
# layers.push(countyLayer201601);
# descrs.push(201601);
# var countyLayer201602 = new L.LayerGroup();
# monthLayers(2016,02,countyLink2016,countyLayer201602);
# layers.push(countyLayer201602);
# descrs.push(201602);
# var countyLayer201603 = new L.LayerGroup();
# monthLayers(2016,03,countyLink2016,countyLayer201603);
# layers.push(countyLayer201603);
# descrs.push(201603);
# var countyLayer201604 = new L.LayerGroup();
# monthLayers(2016,04,countyLink2016,countyLayer201604);
# layers.push(countyLayer201604);
# descrs.push(201604);
# var countyLayer201605 = new L.LayerGroup();
# monthLayers(2016,05,countyLink2016,countyLayer201605);
# layers.push(countyLayer201605);
# descrs.push(201605);
# var countyLayer201606 = new L.LayerGroup();
# monthLayers(2016,06,countyLink2016,countyLayer201606);
# layers.push(countyLayer201606);
# descrs.push(201606);
# var countyLayer201607 = new L.LayerGroup();
# monthLayers(2016,07,countyLink2016,countyLayer201607);
# layers.push(countyLayer201607);
# descrs.push(201607);
# var countyLayer201608 = new L.LayerGroup();
# monthLayers(2016,08,countyLink2016,countyLayer201608);
# layers.push(countyLayer201608);
# descrs.push(201608);
# var countyLayer201609 = new L.LayerGroup();
# monthLayers(2016,09,countyLink2016,countyLayer201609);
# layers.push(countyLayer201609);
# descrs.push(201609);
# var countyLayer201610 = new L.LayerGroup();
# monthLayers(2016,10,countyLink2016,countyLayer201610);
# layers.push(countyLayer201610);
# descrs.push(201610);
# var countyLayer201611 = new L.LayerGroup();
# monthLayers(2016,11,countyLink2016,countyLayer201611);
# layers.push(countyLayer201611);
# descrs.push(201611);
# var countyLayer201612 = new L.LayerGroup();
# monthLayers(2016,12,countyLink2016,countyLayer201612);
# layers.push(countyLayer201612);
# descrs.push(201612);
# var countyLayer201701 = new L.LayerGroup();
# monthLayers(2017,01,countyLink2017,countyLayer201701);
# layers.push(countyLayer201701);
# descrs.push(201701);
# var countyLayer201702 = new L.LayerGroup();
# monthLayers(2017,02,countyLink2017,countyLayer201702);
# layers.push(countyLayer201702);
# descrs.push(201702);
# var countyLayer201703 = new L.LayerGroup();
# monthLayers(2017,03,countyLink2017,countyLayer201703);
# layers.push(countyLayer201703);
# descrs.push(201703);
# var countyLayer201704 = new L.LayerGroup();
# monthLayers(2017,04,countyLink2017,countyLayer201704);
# layers.push(countyLayer201704);
# descrs.push(201704);
# var countyLayer201705 = new L.LayerGroup();
# monthLayers(2017,05,countyLink2017,countyLayer201705);
# layers.push(countyLayer201705);
# descrs.push(201705);
# var countyLayer201706 = new L.LayerGroup();
# monthLayers(2017,06,countyLink2017,countyLayer201706);
# layers.push(countyLayer201706);
# descrs.push(201706);
# var countyLayer201707 = new L.LayerGroup();
# monthLayers(2017,07,countyLink2017,countyLayer201707);
# layers.push(countyLayer201707);
# descrs.push(201707);
# var countyLayer201708 = new L.LayerGroup();
# monthLayers(2017,08,countyLink2017,countyLayer201708);
# layers.push(countyLayer201708);
# descrs.push(201708);
# var countyLayer201709 = new L.LayerGroup();
# monthLayers(2017,09,countyLink2017,countyLayer201709);
# layers.push(countyLayer201709);
# descrs.push(201709);
# var countyLayer201710 = new L.LayerGroup();
# monthLayers(2017,10,countyLink2017,countyLayer201710);
# layers.push(countyLayer201710);
# descrs.push(201710);
# var countyLayer201711 = new L.LayerGroup();
# monthLayers(2017,11,countyLink2017,countyLayer201711);
# layers.push(countyLayer201711);
# descrs.push(201711);
# var countyLayer201712 = new L.LayerGroup();
# monthLayers(2017,12,countyLink2017,countyLayer201712);
# layers.push(countyLayer201712);
# descrs.push(201712);
# var countyLayer201801 = new L.LayerGroup();
# monthLayers(2018,01,countyLink2018,countyLayer201801);
# layers.push(countyLayer201801);
# descrs.push(201801);
# var countyLayer201802 = new L.LayerGroup();
# monthLayers(2018,02,countyLink2018,countyLayer201802);
# layers.push(countyLayer201802);
# descrs.push(201802);
# var countyLayer201803 = new L.LayerGroup();
# monthLayers(2018,03,countyLink2018,countyLayer201803);
# layers.push(countyLayer201803);
# descrs.push(201803);
# var countyLayer201804 = new L.LayerGroup();
# monthLayers(2018,04,countyLink2018,countyLayer201804);
# layers.push(countyLayer201804);
# descrs.push(201804);
# var countyLayer201805 = new L.LayerGroup();
# monthLayers(2018,05,countyLink2018,countyLayer201805);
# layers.push(countyLayer201805);
# descrs.push(201805);
# var countyLayer201806 = new L.LayerGroup();
# monthLayers(2018,06,countyLink2018,countyLayer201806);
# layers.push(countyLayer201806);
# descrs.push(201806);
# var countyLayer201807 = new L.LayerGroup();
# monthLayers(2018,07,countyLink2018,countyLayer201807);
# layers.push(countyLayer201807);
# descrs.push(201807);
# var countyLayer201808 = new L.LayerGroup();
# monthLayers(2018,08,countyLink2018,countyLayer201808);
# layers.push(countyLayer201808);
# descrs.push(201808);
# var countyLayer201809 = new L.LayerGroup();
# monthLayers(2018,09,countyLink2018,countyLayer201809);
# layers.push(countyLayer201809);
# descrs.push(201809);
# var countyLayer201810 = new L.LayerGroup();
# monthLayers(2018,10,countyLink2018,countyLayer201810);
# layers.push(countyLayer201810);
# descrs.push(201810);
# var countyLayer201811 = new L.LayerGroup();
# monthLayers(2018,11,countyLink2018,countyLayer201811);
# layers.push(countyLayer201811);
# descrs.push(201811);
# var countyLayer201812 = new L.LayerGroup();
# monthLayers(2018,12,countyLink2018,countyLayer201812);
# layers.push(countyLayer201812);
# descrs.push(201812);
# var countyLayer201901 = new L.LayerGroup();
# monthLayers(2019,01,countyLink2019,countyLayer201901);
# layers.push(countyLayer201901);
# descrs.push(201901);
# var countyLayer201902 = new L.LayerGroup();
# monthLayers(2019,02,countyLink2019,countyLayer201902);
# layers.push(countyLayer201902);
# descrs.push(201902);
# var countyLayer201903 = new L.LayerGroup();
# monthLayers(2019,03,countyLink2019,countyLayer201903);
# layers.push(countyLayer201903);
# descrs.push(201903);
# var countyLayer201904 = new L.LayerGroup();
# monthLayers(2019,04,countyLink2019,countyLayer201904);
# layers.push(countyLayer201904);
# descrs.push(201904);
# var countyLayer201905 = new L.LayerGroup();
# monthLayers(2019,05,countyLink2019,countyLayer201905);
# layers.push(countyLayer201905);
# descrs.push(201905);
# var countyLayer201906 = new L.LayerGroup();
# monthLayers(2019,06,countyLink2019,countyLayer201906);
# layers.push(countyLayer201906);
# descrs.push(201906);
# var countyLayer201907 = new L.LayerGroup();
# monthLayers(2019,07,countyLink2019,countyLayer201907);
# layers.push(countyLayer201907);
# descrs.push(201907);
# var countyLayer201908 = new L.LayerGroup();
# monthLayers(2019,08,countyLink2019,countyLayer201908);
# layers.push(countyLayer201908);
# descrs.push(201908);
# var countyLayer201909 = new L.LayerGroup();
# monthLayers(2019,09,countyLink2019,countyLayer201909);
# layers.push(countyLayer201909);
# descrs.push(201909);
# var countyLayer201910 = new L.LayerGroup();
# monthLayers(2019,10,countyLink2019,countyLayer201910);
# layers.push(countyLayer201910);
# descrs.push(201910);
# var countyLayer201911 = new L.LayerGroup();
# monthLayers(2019,11,countyLink2019,countyLayer201911);
# layers.push(countyLayer201911);
# descrs.push(201911);
# var countyLayer201912 = new L.LayerGroup();
# monthLayers(2019,12,countyLink2019,countyLayer201912);
# layers.push(countyLayer201912);
# descrs.push(201912);

# %%
def printyearvars(year):
        print(f"var countyLayer{year} = new L.LayerGroup();")
        print(f"yearLayers({year},countyLink{year},countyLayer{year});")
        print(f"layers.push(countyLayer{year});")
        print(f"descrs.push({year});")
for year in range(1990,2020):
    printyearvars(year)
# Out:
# var countyLayer1990 = new L.LayerGroup();
# yearLayers(1990,countyLink1990,countyLayer1990);
# layers.push(countyLayer1990);
# descrs.push(1990);
# var countyLayer1991 = new L.LayerGroup();
# yearLayers(1991,countyLink1991,countyLayer1991);
# layers.push(countyLayer1991);
# descrs.push(1991);
# var countyLayer1992 = new L.LayerGroup();
# yearLayers(1992,countyLink1992,countyLayer1992);
# layers.push(countyLayer1992);
# descrs.push(1992);
# var countyLayer1993 = new L.LayerGroup();
# yearLayers(1993,countyLink1993,countyLayer1993);
# layers.push(countyLayer1993);
# descrs.push(1993);
# var countyLayer1994 = new L.LayerGroup();
# yearLayers(1994,countyLink1994,countyLayer1994);
# layers.push(countyLayer1994);
# descrs.push(1994);
# var countyLayer1995 = new L.LayerGroup();
# yearLayers(1995,countyLink1995,countyLayer1995);
# layers.push(countyLayer1995);
# descrs.push(1995);
# var countyLayer1996 = new L.LayerGroup();
# yearLayers(1996,countyLink1996,countyLayer1996);
# layers.push(countyLayer1996);
# descrs.push(1996);
# var countyLayer1997 = new L.LayerGroup();
# yearLayers(1997,countyLink1997,countyLayer1997);
# layers.push(countyLayer1997);
# descrs.push(1997);
# var countyLayer1998 = new L.LayerGroup();
# yearLayers(1998,countyLink1998,countyLayer1998);
# layers.push(countyLayer1998);
# descrs.push(1998);
# var countyLayer1999 = new L.LayerGroup();
# yearLayers(1999,countyLink1999,countyLayer1999);
# layers.push(countyLayer1999);
# descrs.push(1999);
# var countyLayer2000 = new L.LayerGroup();
# yearLayers(2000,countyLink2000,countyLayer2000);
# layers.push(countyLayer2000);
# descrs.push(2000);
# var countyLayer2001 = new L.LayerGroup();
# yearLayers(2001,countyLink2001,countyLayer2001);
# layers.push(countyLayer2001);
# descrs.push(2001);
# var countyLayer2002 = new L.LayerGroup();
# yearLayers(2002,countyLink2002,countyLayer2002);
# layers.push(countyLayer2002);
# descrs.push(2002);
# var countyLayer2003 = new L.LayerGroup();
# yearLayers(2003,countyLink2003,countyLayer2003);
# layers.push(countyLayer2003);
# descrs.push(2003);
# var countyLayer2004 = new L.LayerGroup();
# yearLayers(2004,countyLink2004,countyLayer2004);
# layers.push(countyLayer2004);
# descrs.push(2004);
# var countyLayer2005 = new L.LayerGroup();
# yearLayers(2005,countyLink2005,countyLayer2005);
# layers.push(countyLayer2005);
# descrs.push(2005);
# var countyLayer2006 = new L.LayerGroup();
# yearLayers(2006,countyLink2006,countyLayer2006);
# layers.push(countyLayer2006);
# descrs.push(2006);
# var countyLayer2007 = new L.LayerGroup();
# yearLayers(2007,countyLink2007,countyLayer2007);
# layers.push(countyLayer2007);
# descrs.push(2007);
# var countyLayer2008 = new L.LayerGroup();
# yearLayers(2008,countyLink2008,countyLayer2008);
# layers.push(countyLayer2008);
# descrs.push(2008);
# var countyLayer2009 = new L.LayerGroup();
# yearLayers(2009,countyLink2009,countyLayer2009);
# layers.push(countyLayer2009);
# descrs.push(2009);
# var countyLayer2010 = new L.LayerGroup();
# yearLayers(2010,countyLink2010,countyLayer2010);
# layers.push(countyLayer2010);
# descrs.push(2010);
# var countyLayer2011 = new L.LayerGroup();
# yearLayers(2011,countyLink2011,countyLayer2011);
# layers.push(countyLayer2011);
# descrs.push(2011);
# var countyLayer2012 = new L.LayerGroup();
# yearLayers(2012,countyLink2012,countyLayer2012);
# layers.push(countyLayer2012);
# descrs.push(2012);
# var countyLayer2013 = new L.LayerGroup();
# yearLayers(2013,countyLink2013,countyLayer2013);
# layers.push(countyLayer2013);
# descrs.push(2013);
# var countyLayer2014 = new L.LayerGroup();
# yearLayers(2014,countyLink2014,countyLayer2014);
# layers.push(countyLayer2014);
# descrs.push(2014);
# var countyLayer2015 = new L.LayerGroup();
# yearLayers(2015,countyLink2015,countyLayer2015);
# layers.push(countyLayer2015);
# descrs.push(2015);
# var countyLayer2016 = new L.LayerGroup();
# yearLayers(2016,countyLink2016,countyLayer2016);
# layers.push(countyLayer2016);
# descrs.push(2016);
# var countyLayer2017 = new L.LayerGroup();
# yearLayers(2017,countyLink2017,countyLayer2017);
# layers.push(countyLayer2017);
# descrs.push(2017);
# var countyLayer2018 = new L.LayerGroup();
# yearLayers(2018,countyLink2018,countyLayer2018);
# layers.push(countyLayer2018);
# descrs.push(2018);
# var countyLayer2019 = new L.LayerGroup();
# yearLayers(2019,countyLink2019,countyLayer2019);
# layers.push(countyLayer2019);
# descrs.push(2019);
